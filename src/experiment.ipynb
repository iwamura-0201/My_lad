# %% [markdown]
# ## 共通

# %%
from pathlib import Path
import pandas as pd
import os
import numpy as np
from tqdm import tqdm
from xml.etree.ElementTree import fromstring, ElementTree
from Evtx.Evtx import Evtx
import csv
import sys

INTERIM_DIR = Path('../data/interim')
PROCESSED_DIR = Path('../data/processed')
RAW_DIR = Path('../data/raw')
NO_MEANING_DIR = Path('../data/no_meaning')

# %%
# %load_ext autoreload
# %autoreload 2
import preprocess

# %%
parent_dir = "ScenarioData"

# %% [markdown]
# ## 実験１：security.csvの欠損値等 把握

# %%
project_name_list = ['T1105', 'VSCode1', 'WEB1', 'WEB2', 'WEB3']

dfs = {}  # プロジェクト名 → DataFrame を入れる辞書

for project_name in project_name_list:
    input_dir = INTERIM_DIR / project_name
    csv_path = input_dir / "security.csv"  # 読み込みたいファイル名に合わせて変更

    df = pd.read_csv(csv_path)
    dfs[project_name] = df

# %%
# 欠損数マトリクス（カラム×project_name）
null_dict = {
    project_name: df.isnull().sum()
    for project_name, df in dfs.items()
}
null_matrix = pd.DataFrame(null_dict).fillna(0).astype(int)

# 各 DataFrame の行数を集める
row_counts = {project_name: len(df) for project_name, df in dfs.items()}

# 一番下に行数の行を追加
null_matrix.loc["__total_rows__"] = pd.Series(row_counts)

# %%
null_matrix
# Out:
#                                 T1105  VSCode1    WEB1    WEB2    WEB3
# Channel                             0        0       0       0       0
# Computer                            0        0       0       0       0
# Content                             2        5       2       2       2
# Correlation_ActivityID         162811    81906  197463  197448  197370
# Correlation_RelatedActivityID  177829    93912  215806  215808  215773
# EventID                             0        0       0       0       0
# EventRecordID                       0        0       0       0       0
# Execution_ProcessID                 0        0       0       0       0
# Execution_ThreadID                  0        0       0       0       0
# Keywords                            0        0       0       0       0
# Label                               0        0       0       0       0
# Level                               0        0       0       0       0
# Opcode                              0        0       0       0       0
# Provider_Guid                       0        0       0       0       0
# Provider_Name                       0        0       0       0       0
# Security_UserID                177829    93912  215806  215808  215773
# Task                                0        0       0       0       0
# TimeCreated_SystemTime              0        0       0       0       0
# Version                             0        0       0       0       0
# date                                0        0       0       0       0
# __total_rows__                 177829    93912  215806  215808  215773

# %%
null_matrix_T = null_matrix.T
null_matrix_T
# Out:
#          Channel  Computer  Content  Correlation_ActivityID  \
# T1105          0         0        2                  162811
# VSCode1        0         0        5                   81906
# WEB1           0         0        2                  197463
# WEB2           0         0        2                  197448
# WEB3           0         0        2                  197370
#
#          Correlation_RelatedActivityID  EventID  EventRecordID  \
# T1105                           177829        0              0
# VSCode1                          93912        0              0
# WEB1                            215806        0              0
# WEB2                            215808        0              0
# WEB3                            215773        0              0
#
#          Execution_ProcessID  Execution_ThreadID  Keywords  ...  Level  \
# T1105                      0                   0         0  ...      0
# VSCode1                    0                   0         0  ...      0
# WEB1                       0                   0         0  ...      0
# WEB2                       0                   0         0  ...      0
# WEB3                       0                   0         0  ...      0
#
#          Opcode  Provider_Guid  Provider_Name  Security_UserID  Task  \
# T1105         0              0              0           177829     0
# VSCode1       0              0              0            93912     0
# WEB1          0              0              0           215806     0
# WEB2          0              0              0           215808     0
# WEB3          0              0              0           215773     0
#
#          TimeCreated_SystemTime  Version  date  __total_rows__
# T1105                         0        0     0          177829
# VSCode1                       0        0     0           93912
# WEB1                          0        0     0          215806
# WEB2                          0        0     0          215808
# WEB3                          0        0     0          215773
#
# [5 rows x 21 columns]

# %% [markdown]
# 結論：
# 全シナリオについて、以下は全行で欠損。
# - Correlation_RelatedActivityID
# - Security_UserID

# %%
time_line = pd.read_csv(RAW_DIR/parent_dir/"T1105/command-and-control_timeline_20240927.csv", encoding="cp932")

# %%
time_line.isnull().sum()
# Out:
# Timestamp         0
# RuleTitle         0
# Level             0
# Computer          0
# Channel           0
# EventID           0
# RecordID          0
# Details           0
# ExtraFieldInfo    0
# dtype: int64

# %% [markdown]
# ## 実験２：パースまで

# %% [markdown]
# TypeError: expected string or bytes-like object, got 'float'
# これはNanによるエラー

# %%
project_name = 'WEB1'
input_dir = INTERIM_DIR/project_name
output_dir = INTERIM_DIR/project_name

# %%
df = pd.read_csv(input_dir/"security.csv")

# %%
# Contentカラムについて処理（欠損値を含む行を削除）
df = df.dropna(subset=["Content"])

# %%
df.to_csv(input_dir / "security_clean.csv", index=False)

# %%
preprocess.parse_log(input_dir=input_dir, output_dir=output_dir, logfile_name='security_clean', parser_type="drain")
# Out:
# Parsing file: ../data/interim/WEB1/security_clean.csv
# Initial DataFrame:
#    Execution_ThreadID   Channel  Level  Opcode   Task  \
# 0                6000  Security      0       0  12804
# 1                6000  Security      0       0  12804
# 2                6000  Security      0       0  12804
# 3                6000  Security      0       0  12804
# 4                5136  Security      0       0  12810
#
#                    Correlation_ActivityID  \
# 0  {326660a5-67c0-0001-6861-6632c067da01}
# 1  {326660a5-67c0-0001-6861-6632c067da01}
# 2  {326660a5-67c0-0001-6861-6632c067da01}
# 3  {326660a5-67c0-0001-6861-6632c067da01}
# 4                                     NaN
#
#                                              Content  Security_UserID  \
# 0  SubjectUserSid=S-1-5-18;SubjectUserName=SWATTC...              NaN
# 1  SubjectUserSid=S-1-5-18;SubjectUserName=SWATTC...              NaN
# 2  SubjectUserSid=S-1-5-18;SubjectUserName=SWATTC...              NaN
# 3  SubjectUserSid=S-1-5-18;SubjectUserName=SWATTC...              NaN
# 4  ProcessId=8596;Application=\device\harddiskvol...              NaN
#
#              TimeCreated_SystemTime  EventID  Execution_ProcessID  \
# 0  2024-03-06 05:48:33.170567+00:00     4702                  692
# 1  2024-03-06 05:48:33.174620+00:00     4702                  692
# 2  2024-03-06 05:48:33.180763+00:00     4702                  692
# 3  2024-03-06 05:48:33.184887+00:00     4702                  692
# 4  2024-03-06 05:48:38.115097+00:00     5158                    4
#
#                             Provider_Guid  \
# 0  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 1  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 2  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 3  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 4  {54849625-5478-4994-a5ba-3e3b0328c30d}
#
#                          Provider_Name  Correlation_RelatedActivityID  \
# 0  Microsoft-Windows-Security-Auditing                            NaN
# 1  Microsoft-Windows-Security-Auditing                            NaN
# 2  Microsoft-Windows-Security-Auditing                            NaN
# 3  Microsoft-Windows-Security-Auditing                            NaN
# 4  Microsoft-Windows-Security-Auditing                            NaN
#
#    Version  EventRecordID            Keywords                Computer
# 0        1        1367106  0x8020000000000000  SWAttckd.swtestnet.com
# 1        1        1367107  0x8020000000000000  SWAttckd.swtestnet.com
# 2        1        1367108  0x8020000000000000  SWAttckd.swtestnet.com
# 3        1        1367109  0x8020000000000000  SWAttckd.swtestnet.com
# 4        0        1367110  0x8020000000000000  SWAttckd.swtestnet.com
# Total size after reading CSV: 215804
# Parsing done. [Time taken: 0:00:42.389961]

# %% [markdown]
# ## 実験３：カラムの削減（T1105のみ）

# %% [markdown]
# 方針：
# - 8/13~9/27までのログであり、量があまりにも膨大(csvでおよそ500M)。
# - WEB系の100M(10日間)を参考に、異常ログを含む形で適当に削減。
# - 削減は"日"単位で行う。
# - 実行ファイルは NO_MEANING_DIR から拾う。**作成の際の上書きに注意**。

# %%
project_name = 'T1105'
ver_number = 2
input_dir = NO_MEANING_DIR/project_name
output_dir = INTERIM_DIR/project_name
data = pd.read_csv(input_dir/f"security{ver_number}.csv")
ano = pd.read_excel(RAW_DIR/parent_dir/project_name/"取りまとめ後参考"/"AtomicRedTeam_Analyze.xlsx", sheet_name="解析結果")

# %%
 # ラベルを取得（インデックスとして扱う準備）
df = pd.DataFrame()
df["Channel"] = ano["Unnamed: 9"].iloc[1:].values
df["EventRecordID"] = ano["Unnamed: 14"].iloc[1:].values

# Securityのみ抽出
df = df[df["Channel"] == 'Sec']

# %%
# Label カラム作成
data["Label"] = "-"

mask = data["EventRecordID"].isin(df["EventRecordID"])
data.loc[mask, "Label"] = "anomaly"

# %%
data[data["Label"] == "anomaly"]
# Out:
#          Level  EventID  EventRecordID            TimeCreated_SystemTime  \
# 1020645      0     4688        4718654  2024-09-26 17:57:13.401667+00:00
# 1020646      0     4688        4718655  2024-09-26 17:57:13.409899+00:00
# 1020647      0     4688        4718656  2024-09-26 17:57:13.442478+00:00
# 1020701      0     4688        4718710  2024-09-26 17:59:47.880032+00:00
# 1020702      0     4688        4718711  2024-09-26 17:59:47.883730+00:00
# ...        ...      ...            ...                               ...
# 1021489      0     5156        4719498  2024-09-26 18:48:50.349300+00:00
# 1021491      0     5156        4719500  2024-09-26 18:48:50.512531+00:00
# 1021494      0     5156        4719503  2024-09-26 18:48:50.929255+00:00
# 1021779      0     4688        4719788  2024-09-26 18:55:46.865633+00:00
# 1021780      0     4688        4719789  2024-09-26 18:55:46.907299+00:00
#
#           Channel   Task                        Provider_Name  \
# 1020645  Security  13312  Microsoft-Windows-Security-Auditing
# 1020646  Security  13312  Microsoft-Windows-Security-Auditing
# 1020647  Security  13312  Microsoft-Windows-Security-Auditing
# 1020701  Security  13312  Microsoft-Windows-Security-Auditing
# 1020702  Security  13312  Microsoft-Windows-Security-Auditing
# ...           ...    ...                                  ...
# 1021489  Security  12810  Microsoft-Windows-Security-Auditing
# 1021491  Security  12810  Microsoft-Windows-Security-Auditing
# 1021494  Security  12810  Microsoft-Windows-Security-Auditing
# 1021779  Security  13312  Microsoft-Windows-Security-Auditing
# 1021780  Security  13312  Microsoft-Windows-Security-Auditing
#
#          Correlation_RelatedActivityID  Execution_ProcessID  \
# 1020645                            NaN                    4
# 1020646                            NaN                    4
# 1020647                            NaN                    4
# 1020701                            NaN                    4
# 1020702                            NaN                    4
# ...                                ...                  ...
# 1021489                            NaN                    4
# 1021491                            NaN                    4
# 1021494                            NaN                    4
# 1021779                            NaN                    4
# 1021780                            NaN                    4
#
#          Execution_ThreadID  Security_UserID            Keywords  \
# 1020645                 300              NaN  0x8020000000000000
# 1020646                  32              NaN  0x8020000000000000
# 1020647                  32              NaN  0x8020000000000000
# 1020701                8064              NaN  0x8020000000000000
# 1020702                8744              NaN  0x8020000000000000
# ...                     ...              ...                 ...
# 1021489                6840              NaN  0x8020000000000000
# 1021491                6840              NaN  0x8020000000000000
# 1021494                 300              NaN  0x8020000000000000
# 1021779                4972              NaN  0x8020000000000000
# 1021780                8308              NaN  0x8020000000000000
#
#                                                    Content  \
# 1020645  SubjectUserSid=S-1-5-21-143320146-2996204461-2...
# 1020646  SubjectUserSid=S-1-5-21-143320146-2996204461-2...
# 1020647  SubjectUserSid=S-1-5-21-143320146-2996204461-2...
# 1020701  SubjectUserSid=S-1-5-21-143320146-2996204461-2...
# 1020702  SubjectUserSid=S-1-5-21-143320146-2996204461-2...
# ...                                                    ...
# 1021489  ProcessID=1284|Application=\device\harddiskvol...
# 1021491  ProcessID=6912|Application=\device\harddiskvol...
# 1021494  ProcessID=6912|Application=\device\harddiskvol...
# 1021779  SubjectUserSid=S-1-5-21-143320146-2996204461-2...
# 1021780  SubjectUserSid=S-1-5-21-143320146-2996204461-2...
#
#         Correlation_ActivityID                           Provider_Guid  \
# 1020645                    NaN  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 1020646                    NaN  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 1020647                    NaN  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 1020701                    NaN  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 1020702                    NaN  {54849625-5478-4994-a5ba-3e3b0328c30d}
# ...                        ...                                     ...
# 1021489                    NaN  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 1021491                    NaN  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 1021494                    NaN  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 1021779                    NaN  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 1021780                    NaN  {54849625-5478-4994-a5ba-3e3b0328c30d}
#
#                        Computer  Opcode  Version    Label
# 1020645  SWAttckd.swtestnet.com       0        2  anomaly
# 1020646  SWAttckd.swtestnet.com       0        2  anomaly
# 1020647  SWAttckd.swtestnet.com       0        2  anomaly
# 1020701  SWAttckd.swtestnet.com       0        2  anomaly
# 1020702  SWAttckd.swtestnet.com       0        2  anomaly
# ...                         ...     ...      ...      ...
# 1021489  SWAttckd.swtestnet.com       0        1  anomaly
# 1021491  SWAttckd.swtestnet.com       0        1  anomaly
# 1021494  SWAttckd.swtestnet.com       0        1  anomaly
# 1021779  SWAttckd.swtestnet.com       0        2  anomaly
# 1021780  SWAttckd.swtestnet.com       0        2  anomaly
#
# [73 rows x 19 columns]

# %% [markdown]
# - 異常ログは9/26に発生している
# - よって、10日間(9/18~9/27)を切り出す。

# %%
data["TimeCreated_SystemTime"] = pd.to_datetime(
    data["TimeCreated_SystemTime"], 
    errors="coerce",      # 変換できないものは NaT にする
)

data["date"] = data["TimeCreated_SystemTime"].dt.date

filtered = data[
    (data["date"] >= pd.to_datetime("2024-09-18").date()) &
    (data["date"] <= pd.to_datetime("2024-09-28").date())
]

# %%
filtered
# Out:
#          Level  EventID  EventRecordID           TimeCreated_SystemTime  \
# 849867       0     5156        4547876 2024-09-18 00:00:14.836159+00:00
# 849868       0     5158        4547877 2024-09-18 00:00:36.620955+00:00
# 849869       0     5156        4547878 2024-09-18 00:00:36.621227+00:00
# 849870       0     5156        4547879 2024-09-18 00:00:55.269754+00:00
# 849871       0     5156        4547880 2024-09-18 00:01:35.623026+00:00
# ...        ...      ...            ...                              ...
# 1027691      0     5156        4725700 2024-09-27 00:07:55.983658+00:00
# 1027692      0     5158        4725701 2024-09-27 00:07:55.987034+00:00
# 1027693      0     5156        4725702 2024-09-27 00:07:55.987099+00:00
# 1027694      0     4688        4725703 2024-09-27 00:07:56.035160+00:00
# 1027695      0     4688        4725704 2024-09-27 00:07:56.045465+00:00
#
#           Channel   Task                        Provider_Name  \
# 849867   Security  12810  Microsoft-Windows-Security-Auditing
# 849868   Security  12810  Microsoft-Windows-Security-Auditing
# 849869   Security  12810  Microsoft-Windows-Security-Auditing
# 849870   Security  12810  Microsoft-Windows-Security-Auditing
# 849871   Security  12810  Microsoft-Windows-Security-Auditing
# ...           ...    ...                                  ...
# 1027691  Security  12810  Microsoft-Windows-Security-Auditing
# 1027692  Security  12810  Microsoft-Windows-Security-Auditing
# 1027693  Security  12810  Microsoft-Windows-Security-Auditing
# 1027694  Security  13312  Microsoft-Windows-Security-Auditing
# 1027695  Security  13312  Microsoft-Windows-Security-Auditing
#
#          Correlation_RelatedActivityID  Execution_ProcessID  \
# 849867                             NaN                    4
# 849868                             NaN                    4
# 849869                             NaN                    4
# 849870                             NaN                    4
# 849871                             NaN                    4
# ...                                ...                  ...
# 1027691                            NaN                    4
# 1027692                            NaN                    4
# 1027693                            NaN                    4
# 1027694                            NaN                    4
# 1027695                            NaN                    4
#
#          Execution_ThreadID  Security_UserID            Keywords  \
# 849867                 2548              NaN  0x8020000000000000
# 849868                 2548              NaN  0x8020000000000000
# 849869                 2548              NaN  0x8020000000000000
# 849870                 2548              NaN  0x8020000000000000
# 849871                 2548              NaN  0x8020000000000000
# ...                     ...              ...                 ...
# 1027691                2684              NaN  0x8020000000000000
# 1027692                8524              NaN  0x8020000000000000
# 1027693                8524              NaN  0x8020000000000000
# 1027694               10016              NaN  0x8020000000000000
# 1027695               10016              NaN  0x8020000000000000
#
#                                                    Content  \
# 849867   ProcessID=5236|Application=\device\harddiskvol...
# 849868   ProcessId=2800|Application=\device\harddiskvol...
# 849869   ProcessID=2800|Application=\device\harddiskvol...
# 849870   ProcessID=5236|Application=\device\harddiskvol...
# 849871   ProcessID=5236|Application=\device\harddiskvol...
# ...                                                    ...
# 1027691  ProcessID=4|Application=System|Direction=%%145...
# 1027692  ProcessId=4|Application=System|SourceAddress=0...
# 1027693  ProcessID=4|Application=System|Direction=%%145...
# 1027694  SubjectUserSid=S-1-5-21-143320146-2996204461-2...
# 1027695  SubjectUserSid=S-1-5-21-143320146-2996204461-2...
#
#         Correlation_ActivityID                           Provider_Guid  \
# 849867                     NaN  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 849868                     NaN  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 849869                     NaN  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 849870                     NaN  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 849871                     NaN  {54849625-5478-4994-a5ba-3e3b0328c30d}
# ...                        ...                                     ...
# 1027691                    NaN  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 1027692                    NaN  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 1027693                    NaN  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 1027694                    NaN  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 1027695                    NaN  {54849625-5478-4994-a5ba-3e3b0328c30d}
#
#                        Computer  Opcode  Version Label        date
# 849867   SWAttckd.swtestnet.com       0        1     -  2024-09-18
# 849868   SWAttckd.swtestnet.com       0        0     -  2024-09-18
# 849869   SWAttckd.swtestnet.com       0        1     -  2024-09-18
# 849870   SWAttckd.swtestnet.com       0        1     -  2024-09-18
# 849871   SWAttckd.swtestnet.com       0        1     -  2024-09-18
# ...                         ...     ...      ...   ...         ...
# 1027691  SWAttckd.swtestnet.com       0        1     -  2024-09-27
# 1027692  SWAttckd.swtestnet.com       0        0     -  2024-09-27
# 1027693  SWAttckd.swtestnet.com       0        1     -  2024-09-27
# 1027694  SWAttckd.swtestnet.com       0        2     -  2024-09-27
# 1027695  SWAttckd.swtestnet.com       0        2     -  2024-09-27
#
# [177829 rows x 20 columns]

# %%
#--------------ファイル上書き注意！！！！！！！！！-----------------#
filtered.to_csv(output_dir/f"security{ver_number}.csv", index=False)

# %% [markdown]
# ## 実験４：モデル前データ作成！

# %% [markdown]
# ### 準備

# %%
project_name = 'T1105'
input_dir = INTERIM_DIR/project_name
output_dir = PROCESSED_DIR/project_name
output_dir.mkdir(exist_ok=True)

# %%
data = pd.read_csv(input_dir/"security_clean_structured.csv")
ano = pd.read_excel(RAW_DIR/parent_dir/project_name/"取りまとめ後参考"/"AtomicRedTeam_Analyze.xlsx", sheet_name="解析結果")

# %%
 # ラベルを取得（インデックスとして扱う準備）
df = pd.DataFrame()
df["Channel"] = ano["Unnamed: 9"].iloc[1:].values
df["EventRecordID"] = ano["Unnamed: 14"].iloc[1:].values

# Securityのみ抽出
df = df[df["Channel"] == 'Sec']

# Label カラム作成
data["Label"] = "-"

mask = data["EventRecordID"].isin(df["EventRecordID"])
data.loc[mask, "Label"] = "anomaly"

# %%
# 諸操作
data["Label"] = data["Label"].apply(lambda x: int(x != "-"))
data["datetime"] = pd.to_datetime(data["TimeCreated_SystemTime"])
data["timestamp"] = data["datetime"].view("int64") // 10**9  
data["deltaT"] = data["datetime"].diff().dt.total_seconds().fillna(0)
# Out:
# /tmp/ipykernel_584155/4072853096.py:4: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   data["timestamp"] = data["datetime"].view("int64") // 10**9

# %%
data
# Out:
#         LineId  Execution_ThreadID  Level  Version  \
# 0            1                2548      0        1
# 1            2                2548      0        0
# 2            3                2548      0        1
# 3            4                2548      0        1
# 4            5                2548      0        1
# ...        ...                 ...    ...      ...
# 177822  177823                2684      0        1
# 177823  177824                8524      0        0
# 177824  177825                8524      0        1
# 177825  177826               10016      0        2
# 177826  177827               10016      0        2
#
#                   TimeCreated_SystemTime  Correlation_RelatedActivityID  \
# 0       2024-09-18 00:00:14.836159+00:00                            NaN
# 1       2024-09-18 00:00:36.620955+00:00                            NaN
# 2       2024-09-18 00:00:36.621227+00:00                            NaN
# 3       2024-09-18 00:00:55.269754+00:00                            NaN
# 4       2024-09-18 00:01:35.623026+00:00                            NaN
# ...                                  ...                            ...
# 177822  2024-09-27 00:07:55.983658+00:00                            NaN
# 177823  2024-09-27 00:07:55.987034+00:00                            NaN
# 177824  2024-09-27 00:07:55.987099+00:00                            NaN
# 177825  2024-09-27 00:07:56.035160+00:00                            NaN
# 177826  2024-09-27 00:07:56.045465+00:00                            NaN
#
#                                  Provider_Guid                Computer  \
# 0       {54849625-5478-4994-a5ba-3e3b0328c30d}  SWAttckd.swtestnet.com
# 1       {54849625-5478-4994-a5ba-3e3b0328c30d}  SWAttckd.swtestnet.com
# 2       {54849625-5478-4994-a5ba-3e3b0328c30d}  SWAttckd.swtestnet.com
# 3       {54849625-5478-4994-a5ba-3e3b0328c30d}  SWAttckd.swtestnet.com
# 4       {54849625-5478-4994-a5ba-3e3b0328c30d}  SWAttckd.swtestnet.com
# ...                                        ...                     ...
# 177822  {54849625-5478-4994-a5ba-3e3b0328c30d}  SWAttckd.swtestnet.com
# 177823  {54849625-5478-4994-a5ba-3e3b0328c30d}  SWAttckd.swtestnet.com
# 177824  {54849625-5478-4994-a5ba-3e3b0328c30d}  SWAttckd.swtestnet.com
# 177825  {54849625-5478-4994-a5ba-3e3b0328c30d}  SWAttckd.swtestnet.com
# 177826  {54849625-5478-4994-a5ba-3e3b0328c30d}  SWAttckd.swtestnet.com
#
#         EventRecordID                        Provider_Name  ...   Task  \
# 0             4547876  Microsoft-Windows-Security-Auditing  ...  12810
# 1             4547877  Microsoft-Windows-Security-Auditing  ...  12810
# 2             4547878  Microsoft-Windows-Security-Auditing  ...  12810
# 3             4547879  Microsoft-Windows-Security-Auditing  ...  12810
# 4             4547880  Microsoft-Windows-Security-Auditing  ...  12810
# ...               ...                                  ...  ...    ...
# 177822        4725700  Microsoft-Windows-Security-Auditing  ...  12810
# 177823        4725701  Microsoft-Windows-Security-Auditing  ...  12810
# 177824        4725702  Microsoft-Windows-Security-Auditing  ...  12810
# 177825        4725703  Microsoft-Windows-Security-Auditing  ...  13312
# 177826        4725704  Microsoft-Windows-Security-Auditing  ...  13312
#
#        EventID  Execution_ProcessID  Label        date   EventId  \
# 0         5156                    4      0  2024-09-18  f469db94
# 1         5158                    4      0  2024-09-18  1bd2065f
# 2         5156                    4      0  2024-09-18  dfb7a98c
# 3         5156                    4      0  2024-09-18  f469db94
# 4         5156                    4      0  2024-09-18  f469db94
# ...        ...                  ...    ...         ...       ...
# 177822    5156                    4      0  2024-09-27  19d38fdc
# 177823    5158                    4      0  2024-09-27  58b8a4e0
# 177824    5156                    4      0  2024-09-27  19d38fdc
# 177825    4688                    4      0  2024-09-27  5b31d60c
# 177826    4688                    4      0  2024-09-27  6153e8a7
#
#                                             EventTemplate  \
# 0       ProcessID=<*>;Application=\device\harddiskvolu...
# 1       ProcessId=<*>;Application=\device\harddiskvolu...
# 2       ProcessID=<*>;Application=\device\harddiskvolu...
# 3       ProcessID=<*>;Application=\device\harddiskvolu...
# 4       ProcessID=<*>;Application=\device\harddiskvolu...
# ...                                                   ...
# 177822  ProcessID=<*>;Application=System;Direction=%%<...
# 177823  ProcessId=<*>;Application=System;SourceAddress...
# 177824  ProcessID=<*>;Application=System;Direction=%%<...
# 177825  SubjectUserSid=S-<*>-<*>;SubjectUserName=taro;...
# 177826  SubjectUserSid=S-<*>-<*>;SubjectUserName=taro;...
#
#                                datetime   timestamp     deltaT
# 0      2024-09-18 00:00:14.836159+00:00  1726617614   0.000000
# 1      2024-09-18 00:00:36.620955+00:00  1726617636  21.784796
# 2      2024-09-18 00:00:36.621227+00:00  1726617636   0.000272
# 3      2024-09-18 00:00:55.269754+00:00  1726617655  18.648527
# 4      2024-09-18 00:01:35.623026+00:00  1726617695  40.353272
# ...                                 ...         ...        ...
# 177822 2024-09-27 00:07:55.983658+00:00  1727395675   0.000048
# 177823 2024-09-27 00:07:55.987034+00:00  1727395675   0.003376
# 177824 2024-09-27 00:07:55.987099+00:00  1727395675   0.000065
# 177825 2024-09-27 00:07:56.035160+00:00  1727395676   0.048061
# 177826 2024-09-27 00:07:56.045465+00:00  1727395676   0.010305
#
# [177827 rows x 26 columns]

# %%
window_size = 5
step_size = 1

# sampling with sliding window
deeplog_df = preprocess.sliding_window(
    data[["timestamp", "Label", "EventId", "deltaT"]],
    para={"window_size": int(window_size) * 60, "step_size": int(step_size) * 60},
)
# Out:
# there are 12742 instances (sliding windows) in this dataset

# %%
# normalとabnormalを切り分け
df_normal = deeplog_df[deeplog_df["Label"] == 0]
df_abnormal = deeplog_df[deeplog_df["Label"] == 1]

df_normal = df_normal.sample(frac=1, random_state=12).reset_index(
    drop=True
)  # shuffle
normal_len = len(df_normal)

# %% [markdown]
# ### 作成

# %%
train_ratio_list = [0.4, 0.6, 0.8]
for train_ratio in train_ratio_list:

    train_len = int(normal_len * train_ratio)
    save_dir = output_dir/f'ratio_{train_ratio}'

    os.makedirs(save_dir, exist_ok=True)

    # train
    train = df_normal[:train_len]
    preprocess.deeplog_file_generator(
        filename = str(save_dir) + '/train',
        df = train,
        features = ["EventId", "deltaT"],
    )
    print("training size {}".format(train_len))

    # test(normal)
    test_normal = df_normal[train_len:]
    preprocess.deeplog_file_generator(
        filename = str(save_dir) + '/test_normal',
        df = test_normal,
        features = ["EventId", "deltaT"],
    )
    print("test normal size {}".format(normal_len - train_len))

    # abnormal
    
    # 必要なら EventId のマッピングを復活
    # df_abnormal["EventId"] = df_abnormal["EventId"].progress_apply(
    #     lambda e: event_index_map[e] if event_index_map.get(e) else UNK
    # )

    preprocess.deeplog_file_generator(
        filename = str(save_dir) + '/test_abnormal',
        df = df_abnormal,
        features = ["EventId", "deltaT"], 
    )
    print("test abnormal size {}".format(len(df_abnormal)))
# Out:
# training size 5076
# test normal size 7615
# test abnormal size 51
# test normal size 7615
# test abnormal size 51
# training size 7614
# training size 7614
# test normal size 5077
# test abnormal size 51
# test normal size 5077
# test abnormal size 51
# training size 10152
# training size 10152
# test normal size 2539
# test abnormal size 51
# test normal size 2539
# test abnormal size 51

# %% [markdown]
# ### 補助実験：vocab用データ作成
# - 完全な正常データ（EventIdのみ）のファイルを作成する
# - 保存先は project_name / vocab 下

# %%
train_ratio = 1.0

train_len = int(normal_len * train_ratio)
save_dir = output_dir/f'vocab'

os.makedirs(save_dir, exist_ok=True)

# train
train = df_normal[:train_len]
preprocess.deeplog_file_generator(
    filename = str(save_dir) + '/train',
    df = train,
    features = ["EventId"], # EventId only
)
print("training size {}".format(train_len))
# Out:
# training size 12691

# %% [markdown]
# ## 実験５：モデル動作検証（training）
# - confはとりあえず「art3.yaml」を参考にした「test.yaml」で指定

# %%
# %load_ext autoreload
# %autoreload 2
import main
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# train
main.main_cli([
    "train",
    "bert/test",           # conf/bert_config_name.yaml
    #"default.device_id=0",        # ここに好きな key=value を並べる
    #"default.epochs=10",
])

# %%
# テスト
main.main_cli([
    "test",  # run_mode
    "outputs/logbert/bert/T1105/ratio_0.6/seq_len_128/r_seed_31/weights/ValTotalbest.pth", # 重みファイルまでの相対パス
    "64",   # eval_batchsize
    "cuda:0",     # gpu
])
# Out:
# ==================================================
# outputs/logbert/bert/T1105/ratio_0.6/seq_len_128/r_seed_31
# ==================================================
# cuda:0 cuda:0
# Building Vocab
# 100%|██████████| 12691/12691 [00:00<00:00, 61864.31it/s]
# VOCAB SIZE: 990
# Processing normal test data: 100%|██████████| 5077/5077 [00:01<00:00, 4061.19it/s]
# Processing abnormal test data: 100%|██████████| 51/51 [00:00<00:00, 3650.21it/s]
# 100%|██████████| 78/78 [00:07<00:00, 10.81it/s]
# 100%|██████████| 51/51 [00:01<00:00, 45.68it/s]
# Saving test normal results
# Saving test abnormal results
# [seq_th, FP, TP, TN, FN, Precision, Recall, F1, TPR, FPR]
# thresholds=0.0['1730.0000', '50.0000', '3262.0000', '1.0000', '2.8090', '98.0392', '5.4615', '34.6554', '98.0392']
# thresholds=0.1['578.0000', '43.0000', '4414.0000', '8.0000', '6.9243', '84.3137', '12.7976', '11.5785', '84.3137']
# thresholds=0.2['189.0000', '33.0000', '4803.0000', '18.0000', '14.8649', '64.7059', '24.1758', '3.7861', '64.7059']
# thresholds=0.3['83.0000', '16.0000', '4909.0000', '35.0000', '16.1616', '31.3725', '21.3333', '1.6627', '31.3725']
# thresholds=0.4['35.0000', '7.0000', '4957.0000', '44.0000', '16.6667', '13.7255', '15.0538', '0.7011', '13.7255']
# thresholds=0.5['14.0000', '0.0000', '4978.0000', '51.0000', '0.0000', '0.0000', '0.0000', '0.2804', '0.0000']
# thresholds=0.6['9.0000', '0.0000', '4983.0000', '51.0000', '0.0000', '0.0000', '0.0000', '0.1803', '0.0000']
# thresholds=0.7['4.0000', '0.0000', '4988.0000', '51.0000', '0.0000', '0.0000', '0.0000', '0.0801', '0.0000']
# thresholds=0.8['1.0000', '0.0000', '4991.0000', '51.0000', '0.0000', '0.0000', '0.0000', '0.0200', '0.0000']
# thresholds=0.9['0.0000', '0.0000', '4992.0000', '51.0000', '0.0000', '0.0000', '0.0000', '0.0000', '0.0000']

# %% [markdown]
# ## 余談

# %% [markdown]
# ### T1105の余事象サブセット作成

# %%
data = pd.read_csv(NO_MEANING_DIR/"T1105"/"security2.csv")

data["TimeCreated_SystemTime"] = pd.to_datetime(
    data["TimeCreated_SystemTime"], 
    errors="coerce",      # 変換できないものは NaT にする
)

data["date"] = data["TimeCreated_SystemTime"].dt.date

filtered = data[
    (data["date"] < pd.to_datetime("2024-09-18").date()) 
]

filtered.to_csv(NO_MEANING_DIR/"T1105"/"security2_complement.csv", index=False)

# %%
filtered
# Out:
#         Level  EventID  EventRecordID           TimeCreated_SystemTime  \
# 0           4     1102        3698009 2024-08-13 09:13:51.656221+00:00
# 1           0     4673        3698010 2024-08-13 09:14:00.897017+00:00
# 2           0     4673        3698011 2024-08-13 09:14:15.903051+00:00
# 3           0     5156        3698012 2024-08-13 09:14:16.729042+00:00
# 4           0     5156        3698013 2024-08-13 09:14:17.731905+00:00
# ...       ...      ...            ...                              ...
# 868046      0     5156        4566055 2024-09-18 23:59:53.532356+00:00
# 868047      0     5156        4566056 2024-09-18 23:59:53.976131+00:00
# 868048      0     5156        4566057 2024-09-18 23:59:53.976151+00:00
# 868049      0     5156        4566058 2024-09-18 23:59:54.286472+00:00
# 868050      0     5156        4566059 2024-09-18 23:59:55.066460+00:00
#
#          Channel   Task                        Provider_Name  \
# 0       Security    104           Microsoft-Windows-Eventlog
# 1       Security  13056  Microsoft-Windows-Security-Auditing
# 2       Security  13056  Microsoft-Windows-Security-Auditing
# 3       Security  12810  Microsoft-Windows-Security-Auditing
# 4       Security  12810  Microsoft-Windows-Security-Auditing
# ...          ...    ...                                  ...
# 868046  Security  12810  Microsoft-Windows-Security-Auditing
# 868047  Security  12810  Microsoft-Windows-Security-Auditing
# 868048  Security  12810  Microsoft-Windows-Security-Auditing
# 868049  Security  12810  Microsoft-Windows-Security-Auditing
# 868050  Security  12810  Microsoft-Windows-Security-Auditing
#
#         Correlation_RelatedActivityID  Execution_ProcessID  \
# 0                                 NaN                 1276
# 1                                 NaN                    4
# 2                                 NaN                    4
# 3                                 NaN                    4
# 4                                 NaN                    4
# ...                               ...                  ...
# 868046                            NaN                    4
# 868047                            NaN                    4
# 868048                            NaN                    4
# 868049                            NaN                    4
# 868050                            NaN                    4
#
#         Execution_ThreadID  Security_UserID            Keywords  \
# 0                    10556              NaN  0x4020000000000000
# 1                     5320              NaN  0x8010000000000000
# 2                     5320              NaN  0x8010000000000000
# 3                     5320              NaN  0x8020000000000000
# 4                     5320              NaN  0x8020000000000000
# ...                    ...              ...                 ...
# 868046                4632              NaN  0x8020000000000000
# 868047                4632              NaN  0x8020000000000000
# 868048                4632              NaN  0x8020000000000000
# 868049                4632              NaN  0x8020000000000000
# 868050                4632              NaN  0x8020000000000000
#
#                                                   Content  \
# 0                                                     NaN
# 1       SubjectUserSid=S-1-5-21-143320146-2996204461-2...
# 2       SubjectUserSid=S-1-5-21-143320146-2996204461-2...
# 3       ProcessID=5216|Application=\device\harddiskvol...
# 4       ProcessID=5216|Application=\device\harddiskvol...
# ...                                                   ...
# 868046  ProcessID=1176|Application=\device\harddiskvol...
# 868047  ProcessID=1176|Application=\device\harddiskvol...
# 868048  ProcessID=1176|Application=\device\harddiskvol...
# 868049  ProcessID=4|Application=System|Direction=%%145...
# 868050  ProcessID=4|Application=System|Direction=%%145...
#
#        Correlation_ActivityID                           Provider_Guid  \
# 0                         NaN  {fc65ddd8-d6ef-4962-83d5-6e5cfe9ce148}
# 1                         NaN  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 2                         NaN  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 3                         NaN  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 4                         NaN  {54849625-5478-4994-a5ba-3e3b0328c30d}
# ...                       ...                                     ...
# 868046                    NaN  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 868047                    NaN  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 868048                    NaN  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 868049                    NaN  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 868050                    NaN  {54849625-5478-4994-a5ba-3e3b0328c30d}
#
#                       Computer  Opcode  Version Label        date
# 0       SWAttckd.swtestnet.com       0        1     -  2024-08-13
# 1       SWAttckd.swtestnet.com       0        0     -  2024-08-13
# 2       SWAttckd.swtestnet.com       0        0     -  2024-08-13
# 3       SWAttckd.swtestnet.com       0        1     -  2024-08-13
# 4       SWAttckd.swtestnet.com       0        1     -  2024-08-13
# ...                        ...     ...      ...   ...         ...
# 868046  SWAttckd.swtestnet.com       0        1     -  2024-09-18
# 868047  SWAttckd.swtestnet.com       0        1     -  2024-09-18
# 868048  SWAttckd.swtestnet.com       0        1     -  2024-09-18
# 868049  SWAttckd.swtestnet.com       0        1     -  2024-09-18
# 868050  SWAttckd.swtestnet.com       0        1     -  2024-09-18
#
# [868047 rows x 20 columns]

# %%
project_name = 'WEB1'
input_dir = INTERIM_DIR/project_name
output_dir = NO_MEANING_DIR/"Windows_5000"

# %%
output_dir.mkdir(exist_ok=True)

# %%
df = pd.read_csv(input_dir/"security2.csv")

df = df.dropna(subset=["Content"])

# 後端5000件を取り出す
last_5000_rows = df.tail(5000)

# 結果を保存
last_5000_rows.to_csv(output_dir/"windows_events_5000_part3.csv", index=False)

# %% [markdown]
# ### LLMParser 用の教師データ作成

# %%
project_name = 'VSCode1'
input_dir = INTERIM_DIR/project_name
output_dir = NO_MEANING_DIR/"Windows_5000"
output_dir.mkdir(exist_ok=True)

# %%
df = pd.read_csv(input_dir / "security.csv")

df = df.dropna(subset=["Content"])

# 抽出数（データ件数が 5000 未満でも動くように調整）
n_samples = min(5000, len(df))

# ランダムに n_samples 行を抽出
sampled_rows = df.sample(n=n_samples, random_state=42)

sampled_rows.to_csv(output_dir / "security_5000.csv", index=False)

# %%
input1 = str(INTERIM_DIR/"T1105"/"security2.csv")
input2 = str(INTERIM_DIR/"VSCode1"/"security2.csv")
input3 = str(INTERIM_DIR/"WEB1"/"security2.csv")

output_dir = str(NO_MEANING_DIR/"Windows_5000") 

sample1, sample2 = preprocess.stratified_sample_by_eventid_two_sets(
    input_files=[input1, input2, input3],
    output_file1=output_dir+"/windows_events_5000_part1.csv",
    output_file2=output_dir+"/windows_events_5000_part2.csv",
    target_n_each=5000,
    event_id_col="EventID",
)
# Out:
# 結合後の全レコード数: 1337414
# サンプル1件数: 5000
# サンプル1除外後の残りレコード数: 1332414
# サンプル2件数: 5000
# サンプル1・2の重複インデックス数: 0
# サンプル1を保存しました: ../data/no_meaning/Windows_5000/windows_events_5000_part1.csv
# サンプル2を保存しました: ../data/no_meaning/Windows_5000/windows_events_5000_part2.csv

# %%
df1 = pd.read_csv(output_dir+"/windows_events_5000_part1.csv")
df2 = pd.read_csv(output_dir+"/windows_events_5000_part2.csv")

df1["EventID"].value_counts()
# Out:
# EventID
# 5156    2380
# 5158    1738
# 4673     264
# 4688     147
# 4702     115
#         ...
# 4614       1
# 4660       1
# 5382       1
# 4616       1
# 5381       1
# Name: count, Length: 65, dtype: int64

# %% [markdown]
# ### 正規表現調整してDrain

# %%
project_name = 'VSCode1'
input_dir = INTERIM_DIR/project_name
output_dir = INTERIM_DIR/project_name

df = pd.read_csv(input_dir/"security2.csv")
df = df.dropna(subset=["Content"]) # Contentカラムに欠損値をもつ行を削除
df.to_csv(input_dir / "security2_clean.csv", index=False)

# %%
preprocess.parse_log(input_dir=input_dir, output_dir=output_dir, logfile_name='security2_clean', parser_type="drain")

# %% [markdown]
# なんかうまくいってそう...

# %%
df["EventID"].value_counts()
# Out:
# EventID
# 5156    25244
# 4673    22852
# 5158    21596
# 5447     6188
# 4688     5687
# 5154     2165
# 4985     2138
# 4702     1449
# 4907     1228
# 4945      626
# 5157      564
# 4627      498
# 4624      498
# 4672      488
# 5379      472
# 4797      223
# 4776      219
# 4625      209
# 4948      178
# 4946      176
# 4798      158
# 4799      144
# 4674      135
# 4957      126
# 4663      123
# 5061      114
# 4611       78
# 4662       59
# 6416       47
# 4697       43
# 4634       34
# 4648       21
# 4622       20
# 5142       13
# 5382       10
# 4698        9
# 4699        8
# 4657        8
# 4616        7
# 4947        6
# 4953        6
# 4701        4
# 4660        4
# 4614        4
# 5140        3
# 4902        2
# 4610        2
# 4826        2
# 4696        2
# 4944        2
# 4718        2
# 4700        2
# 4717        2
# 4779        2
# 4778        2
# 4800        2
# 4647        2
# 4732        1
# Name: count, dtype: int64

# %% [markdown]
# - だいたいイベント数同じ...

# %%
df_ = pd.read_csv(input_dir/"security2_clean_structured.csv")

# %%
df_["pair_id"] = df_.groupby(["EventId", "EventID"]).ngroup() + 1

# %%
df_.to_csv(input_dir/"security2_clean_structured.csv")

# %% [markdown]
# ### Sysmon のパース

# %%
parent_dir = "ScenarioData"
project_name = 'VSCode1'

# %%
# test
input_dir = RAW_DIR/parent_dir/project_name
output_dir = INTERIM_DIR/project_name

preprocess.evtx_to_csv_without_eventdata_columns_samplingver(
    evtx_filepath = input_dir/"20240706063537_7EA74D56-6663-313B-2CC1-A7843FCD1AE6/Evtx/Microsoft-Windows-Sysmon%4Operational.evtx",
    output_dir = output_dir,
    output_filename = "Sysmon_test",
)
# Out:
# Processing records:   1%|          | 4900/839211 [00:00<02:16, 6111.97it/s]
# Writing to CSV: 100%|██████████| 50/50 [00:00<00:00, 19790.05it/s]

# %%
# 実行
input_dir = RAW_DIR/parent_dir/project_name
output_dir = INTERIM_DIR/project_name

preprocess.evtx_to_csv_without_eventdata_columns(
    evtx_filepath = input_dir/"20240706063537_7EA74D56-6663-313B-2CC1-A7843FCD1AE6/Evtx/Microsoft-Windows-Sysmon%4Operational.evtx",
    output_dir = output_dir,
    output_filename = "Sysmon",
)

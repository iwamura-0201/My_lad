# %% [markdown]
# # 1　データ整形：モデル前データまで

# %% [markdown]
# ## 準備

# %%
from pathlib import Path
import pandas as pd
import os
import numpy as np
from tqdm import tqdm
from xml.etree.ElementTree import fromstring, ElementTree
from Evtx.Evtx import Evtx
import csv

# %%
# %load_ext autoreload
# %autoreload 2
import preprocess
import main
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
INTERIM_DIR = Path('../data/interim')
PROCESSED_DIR = Path('../data/processed')
RAW_DIR = Path('../data/raw')

# %% [markdown]
# ## 1-1 AtomicRT（T1105）

# %% [markdown]
# ### processed 作成（使用特徴量：EventId, deltaT）

# %%
input_dir = INTERIM_DIR/project_name
output_dir = PROCESSED_DIR/project_name

# %%
df = pd.read_csv(input_dir / f'{file_name}_prepared_structured.csv')

# 諸操作
df["Label"] = df["Label"].apply(lambda x: int(x != "-"))
df["datetime"] = pd.to_datetime(df["Timestamp"], format="%Y-%m-%d %H:%M:%S.%f %z")
df["timestamp"] = df["datetime"].view("int64") // 10**9  
df["deltaT"] = df["datetime"].diff().dt.total_seconds().fillna(0)
# Out:
# /home/siwamura/lad2/src_/ipykernel_1245661/1067428620.py:6: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
#   df["timestamp"] = df["datetime"].view("int64") // 10**9

# %%
def sliding_window(raw_data, para):
    """
    split logs into sliding windows/session
    :param raw_data: dataframe columns=[timestamp, label, eventid, time duration]
    :param para:{window_size: seconds, step_size: seconds}
    :return: dataframe columns=[eventids, time durations, label]
    """
    log_size = raw_data.shape[0]
    label_data, time_data = raw_data.iloc[:, 1], raw_data.iloc[:, 0]
    logkey_data, deltaT_data = raw_data.iloc[:, 2], raw_data.iloc[:, 3]
    new_data = []
    start_end_index_pair = set()

    start_time = time_data[0]
    end_time = start_time + para["window_size"]
    start_index = 0
    end_index = 0

    # get the first start, end index, end time
    for cur_time in time_data:
        if cur_time < end_time:
            end_index += 1
        else:
            break

    start_end_index_pair.add(tuple([start_index, end_index]))

    # move the start and end index until next sliding window
    num_session = 1
    while end_index < log_size:
        start_time = start_time + para["step_size"]
        end_time = start_time + para["window_size"]
        for i in range(start_index, log_size):
            if time_data[i] < start_time:
                i += 1
            else:
                break
        for j in range(end_index, log_size):
            if time_data[j] < end_time:
                j += 1
            else:
                break
        start_index = i
        end_index = j

        # when start_index == end_index, there is no value in the window
        if start_index != end_index:
            start_end_index_pair.add(tuple([start_index, end_index]))

        num_session += 1
        if num_session % 1000 == 0:
            print("process {} time window".format(num_session), end="\r")

    for start_index, end_index in start_end_index_pair:
        dt = deltaT_data[start_index:end_index].values
        dt[0] = 0
        new_data.append(
            [
                time_data[start_index:end_index].values,
                max(label_data[start_index:end_index]),
                logkey_data[start_index:end_index].values,
                dt,
            ]
        )

    assert len(start_end_index_pair) == len(new_data)
    print(
        "there are %d instances (sliding windows) in this dataset\n"
        % len(start_end_index_pair)
    )
    return pd.DataFrame(new_data, columns=raw_data.columns)

# dfをdeeplog_fileに変換
def deeplog_file_generator(filename, df, features):
    with open(filename, "w") as f:
        for _, row in df.iterrows():
            for val in zip(*row[features]):
                f.write(",".join([str(v) for v in val]) + " ")
            f.write("\n")

# %%
window_size = 5
step_size = 1

# sampling with sliding window
deeplog_df = sliding_window(
    df[["timestamp", "Label", "EventId", "deltaT"]],
    para={"window_size": int(window_size) * 60, "step_size": int(step_size) * 60},
)
# Out:
# there are 820 instances (sliding windows) in this dataset

# %%
# normalとabnormalを切り分け
df_normal = deeplog_df[deeplog_df["Label"] == 0]
df_abnormal = deeplog_df[deeplog_df["Label"] == 1]

df_normal = df_normal.sample(frac=1, random_state=12).reset_index(
    drop=True
)  # shuffle
normal_len = len(df_normal)

# %%
df_abnormal
# Out:
# Empty DataFrame
# Columns: [timestamp, Label, EventId, deltaT]
# Index: []

# %% [markdown]
# ##### train_ratio = 40%, 60%, 80%

# %%
# 案１（ファイル名を分けない）
train_ratio_list = [0.4, 0.6, 0.8]
for train_ratio in train_ratio_list:

    train_len = int(normal_len * train_ratio)
    save_dir = output_dir/f'ratio_{train_ratio}'

    os.makedirs(save_dir, exist_ok=True)

    # train
    train = df_normal[:train_len]
    deeplog_file_generator(
        filename = str(save_dir) + '/train',
        df = train,
        features = ["EventId", "deltaT"],
    )
    print("training size {}".format(train_len))

    # test(normal)
    test_normal = df_normal[train_len:]
    deeplog_file_generator(
        filename = str(save_dir) + '/test_normal',
        df = test_normal,
        features = ["EventId", "deltaT"],
    )
    print("test normal size {}".format(normal_len - train_len))

    # abnormal
    
    # 必要なら EventId のマッピングを復活
    # df_abnormal["EventId"] = df_abnormal["EventId"].progress_apply(
    #     lambda e: event_index_map[e] if event_index_map.get(e) else UNK
    # )

    deeplog_file_generator(
        filename = str(save_dir) + '/test_abnormal',
        df = df_abnormal,
        features = ["EventId", "deltaT"], 
    )
    print("test abnormal size {}".format(len(df_abnormal)))
# Out:
# training size 328
# test normal size 492
# test abnormal size 0
# training size 492
# test normal size 328
# test abnormal size 0
# training size 656
# test normal size 164
# test abnormal size 0

# %%
# 案２（それぞれファイル名を分ける）

# train
train = df_normal[:train_len]
deeplog_file_generator(
    filename = str(save_dir) + f'/train_{train_ratio}',
    df = train,
    features = ["EventId", "deltaT"],
)
print("training size {}".format(train_len))

# test
test_normal = df_normal[train_len:]
deeplog_file_generator(
    filename = str(save_dir) + f'/test_{(1.0 - train_ratio):.1f}',
    df = test_normal,
    features = ["EventId", "deltaT"],
)

# %% [markdown]
# ## 1-1 T1105
# - interim下にあるsecurity.csvは10日間を抽出したものであることに注意（コードに反映していない）

# %% [markdown]
# ### 準備

# %%
parent_dir = "ScenarioData"
project_name = 'T1105'
ver_number = "1"

# %% [markdown]
# ### evtx → csv

# %%
# test
input_dir = RAW_DIR/parent_dir/project_name
output_dir = INTERIM_DIR/project_name

preprocess.evtx_to_csv_without_eventdata_columns_samplingver(
    evtx_filepath = input_dir/"20240927120753_7EA74D56-6663-313B-2CC1-A7843FCD1AE6/Evtx/Security.evtx",
    output_dir = output_dir,
    output_filename = "security2_test",
)
# Out:
# Processing records:   0%|          | 4900/1027696 [00:00<02:01, 8434.40it/s]
# Writing to CSV: 100%|██████████| 50/50 [00:00<00:00, 71453.22it/s]

# %%
# 実行
preprocess.evtx_to_csv_without_eventdata_columns(
    evtx_filepath = input_dir/"20240927120753_7EA74D56-6663-313B-2CC1-A7843FCD1AE6/Evtx/Security.evtx",
    output_dir = output_dir,
    output_filename = "security2",
)
# Out:
# Processing records: 100%|██████████| 1027696/1027696 [1:57:49<00:00, 145.36it/s]
# Writing to CSV: 100%|██████████| 1027696/1027696 [00:13<00:00, 74554.24it/s]

# %% [markdown]
# ### xml(過去7日間) → csv

# %%
# 実行
preprocess.xml_to_csv_parse(
    evtx_filepath = input_dir/"20240927120753_7EA74D56-6663-313B-2CC1-A7843FCD1AE6/Evtx/Security.evtx",
    output_dir = output_dir,
    output_filename = "security",
)

# %% [markdown]
# ### パース(Drain)
# - ここからのsecurity.csvは10日間を抽出したものを想定！！！！！！！！！！！！！！！！

# %%
input_dir = INTERIM_DIR/project_name
output_dir = INTERIM_DIR/project_name

df = pd.read_csv(input_dir/f"security{ver_number}.csv")
df = df.dropna(subset=["Content"]) # Contentカラムに欠損値をもつ行を削除
df.to_csv(input_dir / f"security{ver_number}_clean.csv", index=False)

# %%
preprocess.parse_log(input_dir=input_dir, output_dir=output_dir, logfile_name=f'security{ver_number}_clean', parser_type="drain")
# Out:
# Parsing file: ../data/interim/T1105/security2_clean.csv
# Total size after reading CSV: 177827
# Parsing done. [Time taken: 0:00:16.855435]

# %% [markdown]
# ### モデル前データ作成

# %%
ver_number = "2"
input_dir = INTERIM_DIR/project_name
output_dir = PROCESSED_DIR/project_name/f"ver_{ver_number}"
output_dir.mkdir(exist_ok=True)

ano = pd.read_excel(RAW_DIR/parent_dir/project_name/"取りまとめ後参考"/"AtomicRedTeam_Analyze.xlsx", sheet_name="解析結果")
df = pd.DataFrame()
df["Channel"] = ano["Unnamed: 9"].iloc[1:].values
df["EventRecordID"] = ano["Unnamed: 14"].iloc[1:].values


preprocess.prepare_model_data(
    logdata_filepath = Path(input_dir/"security2_clean_structured.csv"),
    output_dir = output_dir,
    ano_df = df,
)
# Out:
# /home/siwamura/lad2/src/preprocess.py:14: FutureWarning: Series.view is deprecated and will be removed in a future version. Use ``astype`` as an alternative to change the dtype.
# there are 10396 instances (sliding windows) in this dataset
#
# training size 4137
# test normal size 6206
# test abnormal size 53
# training size 6205
# test normal size 4138
# test abnormal size 53
# training size 8274
# test normal size 2069
# test abnormal size 53
# training size 10343

# %% [markdown]
# ### training

# %%
# train
main.main_cli([
    "train",
    "bert/test3",           # conf/bert_config_name.yaml
    #"default.device_id=0",        # ここに好きな key=value を並べる
    #"default.epochs=10",
    "dataset.sample.seq_len=128",
])
# Out:
# setup
# Building Vocab
#   0%|          | 0/10343 [00:00<?, ?it/s]
# 100%|██████████| 10343/10343 [00:00<00:00, 67987.32it/s]
# VOCAB SIZE: 55
# before filtering short session
# train size  7447
# valid size  827
# ========================================
# 100%|██████████| 8274/8274 [00:02<00:00, 3967.28it/s]
# ========================================
# Num of train seqs 7412
# Num of valid seqs 827
# ========================================
# 231it [00:07, 29.19it/s]
# 25it [00:00, 85.29it/s]
# epoch 1 || TRAIN_Loss:8.1183 ||VAL_Loss:6.2653
# Best epoch = 1
# 231it [00:08, 26.35it/s]
# 25it [00:00, 81.55it/s]
# epoch 2 || TRAIN_Loss:2.2379 ||VAL_Loss:1.4658
# Best epoch = 2
# 231it [00:08, 26.62it/s]
# 25it [00:00, 79.20it/s]
# epoch 3 || TRAIN_Loss:1.4383 ||VAL_Loss:1.2050
# Best epoch = 3
# 231it [00:08, 27.92it/s]
# 25it [00:00, 83.44it/s]
# epoch 4 || TRAIN_Loss:1.2272 ||VAL_Loss:1.0727
# Best epoch = 4
# 231it [00:08, 26.43it/s]
# 25it [00:00, 78.94it/s]
# epoch 5 || TRAIN_Loss:1.1425 ||VAL_Loss:1.0441
# Best epoch = 5
# 231it [00:08, 26.60it/s]
# 25it [00:00, 75.47it/s]
# epoch 6 || TRAIN_Loss:1.1047 ||VAL_Loss:1.0167
# Best epoch = 6
# 231it [00:08, 26.25it/s]
# 25it [00:00, 74.87it/s]
# epoch 7 || TRAIN_Loss:1.0790 ||VAL_Loss:0.9923
# Best epoch = 7
# 231it [00:08, 26.32it/s]
# 25it [00:00, 77.89it/s]
# epoch 8 || TRAIN_Loss:1.0570 ||VAL_Loss:0.9776
# Best epoch = 8
# 231it [00:08, 26.10it/s]
# 25it [00:00, 79.90it/s]
# epoch 9 || TRAIN_Loss:1.0385 ||VAL_Loss:0.9536
# Best epoch = 9
# 231it [00:08, 26.18it/s]
# 25it [00:00, 73.13it/s]
# epoch 10 || TRAIN_Loss:1.0257 ||VAL_Loss:0.9513
# Best epoch = 10
# 231it [00:08, 25.99it/s]
# 25it [00:00, 78.37it/s]
# epoch 11 || TRAIN_Loss:1.0177 ||VAL_Loss:0.9437
# Best epoch = 11
# 231it [00:08, 26.21it/s]
# 25it [00:00, 74.50it/s]
# epoch 12 || TRAIN_Loss:1.0084 ||VAL_Loss:0.9465
# Best epoch = 11
# 231it [00:08, 28.40it/s]
# 25it [00:00, 82.81it/s]
# epoch 13 || TRAIN_Loss:1.0045 ||VAL_Loss:0.9402
# Best epoch = 13
# 231it [00:08, 26.26it/s]
# 25it [00:00, 74.14it/s]
# epoch 14 || TRAIN_Loss:0.9996 ||VAL_Loss:0.9289
# Best epoch = 14
# 231it [00:08, 26.14it/s]
# 25it [00:00, 75.10it/s]
# epoch 15 || TRAIN_Loss:0.9973 ||VAL_Loss:0.9260
# Best epoch = 15
# 231it [00:08, 27.46it/s]
# 25it [00:00, 76.46it/s]
# epoch 16 || TRAIN_Loss:0.9922 ||VAL_Loss:0.9306
# Best epoch = 15
# 231it [00:08, 27.09it/s]
# 25it [00:00, 74.13it/s]
# epoch 17 || TRAIN_Loss:0.9880 ||VAL_Loss:0.9295
# Best epoch = 15
# 231it [00:08, 26.33it/s]
# 25it [00:00, 76.91it/s]
# epoch 18 || TRAIN_Loss:0.9851 ||VAL_Loss:0.9161
# Best epoch = 18
# 231it [00:08, 28.44it/s]
# 25it [00:00, 73.78it/s]
# epoch 19 || TRAIN_Loss:0.9814 ||VAL_Loss:0.9177
# Best epoch = 18
# 231it [00:08, 28.23it/s]
# 25it [00:00, 77.52it/s]
# epoch 20 || TRAIN_Loss:0.9790 ||VAL_Loss:0.9247
# Best epoch = 18
# 231it [00:08, 28.16it/s]
# 25it [00:00, 72.74it/s]
# epoch 21 || TRAIN_Loss:0.9764 ||VAL_Loss:0.9192
# Best epoch = 18
# 231it [00:08, 28.24it/s]
# 25it [00:00, 71.47it/s]
# epoch 22 || TRAIN_Loss:0.9752 ||VAL_Loss:0.9252
# Best epoch = 18
# 231it [00:08, 28.25it/s]
# 25it [00:00, 80.76it/s]
# epoch 23 || TRAIN_Loss:0.9749 ||VAL_Loss:0.9192
# Best epoch = 18
# 231it [00:08, 26.05it/s]
# 25it [00:00, 75.80it/s]
# epoch 24 || TRAIN_Loss:0.9697 ||VAL_Loss:0.9189
# Best epoch = 18
# 231it [00:08, 26.90it/s]
# 25it [00:00, 76.45it/s]
# epoch 25 || TRAIN_Loss:0.9710 ||VAL_Loss:0.9146
# Best epoch = 25
# 231it [00:08, 26.11it/s]
# 25it [00:00, 76.38it/s]
# epoch 26 || TRAIN_Loss:0.9688 ||VAL_Loss:0.9178
# Best epoch = 25
# 231it [00:08, 28.11it/s]
# 25it [00:00, 76.01it/s]
# epoch 27 || TRAIN_Loss:0.9673 ||VAL_Loss:0.9173
# Best epoch = 25
# 231it [00:08, 28.24it/s]
# 25it [00:00, 74.36it/s]
# epoch 28 || TRAIN_Loss:0.9638 ||VAL_Loss:0.9083
# Best epoch = 28
# 231it [00:08, 26.06it/s]
# 25it [00:00, 73.04it/s]
# epoch 29 || TRAIN_Loss:0.9615 ||VAL_Loss:0.9209
# Best epoch = 28
# 231it [00:08, 28.39it/s]
# 25it [00:00, 73.33it/s]
# epoch 30 || TRAIN_Loss:0.9591 ||VAL_Loss:0.9147
# Best epoch = 28
# 231it [00:08, 26.09it/s]
# 25it [00:00, 70.71it/s]
# epoch 31 || TRAIN_Loss:0.9585 ||VAL_Loss:0.9112
# Best epoch = 28
# 231it [00:08, 28.25it/s]
# 25it [00:00, 71.83it/s]
# epoch 32 || TRAIN_Loss:0.9589 ||VAL_Loss:0.9119
# Best epoch = 28
# 231it [00:08, 28.22it/s]
# 25it [00:00, 74.13it/s]
# epoch 33 || TRAIN_Loss:0.9580 ||VAL_Loss:0.9032
# Best epoch = 33
# 231it [00:08, 26.09it/s]
# 25it [00:00, 75.08it/s]
# epoch 34 || TRAIN_Loss:0.9569 ||VAL_Loss:0.9086
# Best epoch = 33
# 231it [00:08, 28.26it/s]
# 25it [00:00, 74.83it/s]
# epoch 35 || TRAIN_Loss:0.9559 ||VAL_Loss:0.9119
# Best epoch = 33
# 231it [00:08, 28.25it/s]
# 25it [00:00, 76.47it/s]
# epoch 36 || TRAIN_Loss:0.9567 ||VAL_Loss:0.9047
# Best epoch = 33
# 231it [00:08, 28.21it/s]
# 25it [00:00, 79.36it/s]
# epoch 37 || TRAIN_Loss:0.9529 ||VAL_Loss:0.9097
# Best epoch = 33
# 231it [00:08, 28.23it/s]
# 25it [00:00, 72.59it/s]
# epoch 38 || TRAIN_Loss:0.9518 ||VAL_Loss:0.9107
# Best epoch = 33
# 231it [00:08, 25.82it/s]
# 25it [00:00, 73.16it/s]
# epoch 39 || TRAIN_Loss:0.9519 ||VAL_Loss:0.9114
# Best epoch = 33
# 231it [00:08, 25.99it/s]
# 25it [00:00, 75.84it/s]
# epoch 40 || TRAIN_Loss:0.9492 ||VAL_Loss:0.9151
# Best epoch = 33
# 231it [00:08, 28.15it/s]
# 25it [00:00, 77.56it/s]
# epoch 41 || TRAIN_Loss:0.9488 ||VAL_Loss:0.9049
# Best epoch = 33
# 231it [00:08, 28.24it/s]
# 25it [00:00, 75.37it/s]
# epoch 42 || TRAIN_Loss:0.9465 ||VAL_Loss:0.8970
# Best epoch = 42
# 231it [00:08, 25.80it/s]
# 25it [00:00, 77.10it/s]
# epoch 43 || TRAIN_Loss:0.9449 ||VAL_Loss:0.9068
# Best epoch = 42
# 231it [00:08, 28.19it/s]
# 25it [00:00, 71.23it/s]
# epoch 44 || TRAIN_Loss:0.9452 ||VAL_Loss:0.9037
# Best epoch = 42
# 231it [00:08, 28.19it/s]
# 25it [00:00, 71.98it/s]
# epoch 45 || TRAIN_Loss:0.9456 ||VAL_Loss:0.9042
# Best epoch = 42
# 231it [00:08, 28.14it/s]
# 25it [00:00, 74.52it/s]
# epoch 46 || TRAIN_Loss:0.9454 ||VAL_Loss:0.9009
# Best epoch = 42
# 231it [00:08, 28.19it/s]
# 25it [00:00, 74.46it/s]
# epoch 47 || TRAIN_Loss:0.9432 ||VAL_Loss:0.9057
# Best epoch = 42
# 231it [00:08, 28.19it/s]
# 25it [00:00, 73.08it/s]
# epoch 48 || TRAIN_Loss:0.9444 ||VAL_Loss:0.8990
# Best epoch = 42
# 231it [00:08, 25.95it/s]
# 25it [00:00, 75.98it/s]
# epoch 49 || TRAIN_Loss:0.9433 ||VAL_Loss:0.9099
# Best epoch = 42
# 231it [00:08, 28.10it/s]
# 25it [00:00, 75.67it/s]
# epoch 50 || TRAIN_Loss:0.9432 ||VAL_Loss:0.9076
# Best epoch = 42
# 231it [00:08, 27.52it/s]
# 25it [00:00, 75.01it/s]
# epoch 51 || TRAIN_Loss:0.9422 ||VAL_Loss:0.9024
# Best epoch = 42
# 231it [00:08, 27.98it/s]
# 25it [00:00, 74.18it/s]
# epoch 52 || TRAIN_Loss:0.9433 ||VAL_Loss:0.8983
# Best epoch = 42
# 231it [00:08, 28.06it/s]
# 25it [00:00, 74.17it/s]
# epoch 53 || TRAIN_Loss:0.9401 ||VAL_Loss:0.9035
# Best epoch = 42
# 231it [00:08, 28.12it/s]
# 25it [00:00, 75.90it/s]
# epoch 54 || TRAIN_Loss:0.9380 ||VAL_Loss:0.9005
# Best epoch = 42
# 231it [00:08, 28.11it/s]
# 25it [00:00, 73.96it/s]
# epoch 55 || TRAIN_Loss:0.9395 ||VAL_Loss:0.8998
# Best epoch = 42
# 231it [00:08, 25.91it/s]
# 25it [00:00, 72.88it/s]
# epoch 56 || TRAIN_Loss:0.9378 ||VAL_Loss:0.8969
# Best epoch = 56
# 231it [00:08, 25.98it/s]
# 25it [00:00, 78.23it/s]
# epoch 57 || TRAIN_Loss:0.9399 ||VAL_Loss:0.8992
# Best epoch = 56
# 231it [00:08, 28.05it/s]
# 25it [00:00, 71.39it/s]
# epoch 58 || TRAIN_Loss:0.9364 ||VAL_Loss:0.9000
# Best epoch = 56
# 231it [00:08, 28.19it/s]
# 25it [00:00, 77.95it/s]
# epoch 59 || TRAIN_Loss:0.9368 ||VAL_Loss:0.8959
# Best epoch = 59
# 231it [00:08, 25.99it/s]
# 25it [00:00, 71.44it/s]
# epoch 60 || TRAIN_Loss:0.9353 ||VAL_Loss:0.8997
# Best epoch = 59
# 231it [00:08, 28.16it/s]
# 25it [00:00, 78.50it/s]
# epoch 61 || TRAIN_Loss:0.9304 ||VAL_Loss:0.9026
# Best epoch = 59
# 231it [00:08, 25.73it/s]
# 25it [00:00, 77.26it/s]
# epoch 62 || TRAIN_Loss:0.9310 ||VAL_Loss:0.8898
# Best epoch = 62
# 231it [00:08, 28.02it/s]
# 25it [00:00, 71.81it/s]
# epoch 63 || TRAIN_Loss:0.9319 ||VAL_Loss:0.8917
# Best epoch = 62
# 231it [00:08, 26.81it/s]
# 25it [00:00, 75.97it/s]
# epoch 64 || TRAIN_Loss:0.9328 ||VAL_Loss:0.8920
# Best epoch = 62
# 231it [00:08, 28.12it/s]
# 25it [00:00, 73.38it/s]
# epoch 65 || TRAIN_Loss:0.9313 ||VAL_Loss:0.8961
# Best epoch = 62
# 231it [00:08, 28.15it/s]
# 25it [00:00, 72.89it/s]
# epoch 66 || TRAIN_Loss:0.9311 ||VAL_Loss:0.8853
# Best epoch = 66
# 231it [00:08, 25.99it/s]
# 25it [00:00, 74.30it/s]
# epoch 67 || TRAIN_Loss:0.9293 ||VAL_Loss:0.9039
# Best epoch = 66
# 231it [00:08, 26.03it/s]
# 25it [00:00, 75.23it/s]
# epoch 68 || TRAIN_Loss:0.9283 ||VAL_Loss:0.8967
# Best epoch = 66
# 231it [00:08, 25.94it/s]
# 25it [00:00, 73.22it/s]
# epoch 69 || TRAIN_Loss:0.9301 ||VAL_Loss:0.8931
# Best epoch = 66
# 231it [00:08, 28.05it/s]
# 25it [00:00, 71.73it/s]
# epoch 70 || TRAIN_Loss:0.9281 ||VAL_Loss:0.8955
# Best epoch = 66
# 231it [00:08, 28.14it/s]
# 25it [00:00, 76.15it/s]
# epoch 71 || TRAIN_Loss:0.9271 ||VAL_Loss:0.8890
# Best epoch = 66
# 231it [00:08, 28.06it/s]
# 25it [00:00, 74.72it/s]
# epoch 72 || TRAIN_Loss:0.9294 ||VAL_Loss:0.8891
# Best epoch = 66
# 231it [00:08, 28.09it/s]
# 25it [00:00, 72.60it/s]
# epoch 73 || TRAIN_Loss:0.9261 ||VAL_Loss:0.8963
# Best epoch = 66
# 231it [00:08, 28.04it/s]
# 25it [00:00, 77.97it/s]
# epoch 74 || TRAIN_Loss:0.9241 ||VAL_Loss:0.8959
# Best epoch = 66
# 231it [00:08, 28.15it/s]
# 25it [00:00, 76.12it/s]
# epoch 75 || TRAIN_Loss:0.9282 ||VAL_Loss:0.8951
# Best epoch = 66
# 231it [00:08, 25.99it/s]
# 25it [00:00, 71.59it/s]
# epoch 76 || TRAIN_Loss:0.9262 ||VAL_Loss:0.8913
# Best epoch = 66
# 231it [00:08, 26.02it/s]
# 25it [00:00, 69.61it/s]
# epoch 77 || TRAIN_Loss:0.9251 ||VAL_Loss:0.8894
# Best epoch = 66
# 231it [00:08, 26.07it/s]
# 25it [00:00, 71.99it/s]
# epoch 78 || TRAIN_Loss:0.9243 ||VAL_Loss:0.8967
# Best epoch = 66
# 231it [00:08, 25.83it/s]
# 25it [00:00, 72.68it/s]
# epoch 79 || TRAIN_Loss:0.9231 ||VAL_Loss:0.8847
# Best epoch = 79
# 231it [00:08, 25.97it/s]
# 25it [00:00, 74.36it/s]
# epoch 80 || TRAIN_Loss:0.9223 ||VAL_Loss:0.8867
# Best epoch = 79
# 231it [00:08, 25.89it/s]
# 25it [00:00, 73.91it/s]
# epoch 81 || TRAIN_Loss:0.9220 ||VAL_Loss:0.8923
# Best epoch = 79
# 231it [00:08, 26.07it/s]
# 25it [00:00, 71.30it/s]
# epoch 82 || TRAIN_Loss:0.9194 ||VAL_Loss:0.8885
# Best epoch = 79
# 231it [00:08, 28.28it/s]
# 25it [00:00, 74.23it/s]
# epoch 83 || TRAIN_Loss:0.9216 ||VAL_Loss:0.8884
# Best epoch = 79
# 231it [00:08, 28.16it/s]
# 25it [00:00, 75.81it/s]
# epoch 84 || TRAIN_Loss:0.9198 ||VAL_Loss:0.8902
# Best epoch = 79
# 231it [00:08, 25.90it/s]
# 25it [00:00, 74.60it/s]
# epoch 85 || TRAIN_Loss:0.9194 ||VAL_Loss:0.8831
# Best epoch = 85
# 231it [00:08, 25.88it/s]
# 25it [00:00, 77.04it/s]
# epoch 86 || TRAIN_Loss:0.9190 ||VAL_Loss:0.8805
# Best epoch = 86
# 231it [00:08, 26.33it/s]
# 25it [00:00, 77.03it/s]
# epoch 87 || TRAIN_Loss:0.9175 ||VAL_Loss:0.8840
# Best epoch = 86
# 231it [00:08, 25.92it/s]
# 25it [00:00, 74.19it/s]
# epoch 88 || TRAIN_Loss:0.9169 ||VAL_Loss:0.8935
# Best epoch = 86
# 231it [00:08, 28.30it/s]
# 25it [00:00, 74.72it/s]
# epoch 89 || TRAIN_Loss:0.9173 ||VAL_Loss:0.8849
# Best epoch = 86
# 231it [00:08, 28.29it/s]
# 25it [00:00, 70.20it/s]
# epoch 90 || TRAIN_Loss:0.9167 ||VAL_Loss:0.8791
# Best epoch = 90
# 231it [00:08, 27.46it/s]
# 25it [00:00, 75.80it/s]
# epoch 91 || TRAIN_Loss:0.9159 ||VAL_Loss:0.8884
# Best epoch = 90
# 231it [00:08, 28.18it/s]
# 25it [00:00, 77.25it/s]
# epoch 92 || TRAIN_Loss:0.9148 ||VAL_Loss:0.8802
# Best epoch = 90
# 231it [00:08, 28.31it/s]
# 25it [00:00, 75.83it/s]
# epoch 93 || TRAIN_Loss:0.9157 ||VAL_Loss:0.8838
# Best epoch = 90
# 231it [00:08, 25.84it/s]
# 25it [00:00, 71.74it/s]
# epoch 94 || TRAIN_Loss:0.9144 ||VAL_Loss:0.8854
# Best epoch = 90
# 231it [00:08, 25.98it/s]
# 25it [00:00, 75.85it/s]
# epoch 95 || TRAIN_Loss:0.9136 ||VAL_Loss:0.8741
# Best epoch = 95
# 231it [00:08, 26.05it/s]
# 25it [00:00, 73.11it/s]
# epoch 96 || TRAIN_Loss:0.9132 ||VAL_Loss:0.8788
# Best epoch = 95
# 231it [00:08, 28.03it/s]
# 25it [00:00, 72.69it/s]
# epoch 97 || TRAIN_Loss:0.9115 ||VAL_Loss:0.8812
# Best epoch = 95
# 231it [00:08, 28.29it/s]
# 25it [00:00, 71.54it/s]
# epoch 98 || TRAIN_Loss:0.9109 ||VAL_Loss:0.8814
# Best epoch = 95
# 231it [00:08, 28.06it/s]
# 25it [00:00, 75.12it/s]
# epoch 99 || TRAIN_Loss:0.9123 ||VAL_Loss:0.8778
# Best epoch = 95
# 231it [00:08, 28.28it/s]
# 25it [00:00, 78.41it/s]
# epoch 100 || TRAIN_Loss:0.9107 ||VAL_Loss:0.8856
# Best epoch = 95
# 231it [00:08, 28.09it/s]
# 25it [00:00, 74.96it/s]
# epoch 101 || TRAIN_Loss:0.9104 ||VAL_Loss:0.8757
# Best epoch = 95
# 231it [00:08, 26.08it/s]
# 25it [00:00, 73.51it/s]
# epoch 102 || TRAIN_Loss:0.9110 ||VAL_Loss:0.8672
# Best epoch = 102
# 231it [00:08, 26.08it/s]
# 25it [00:00, 76.04it/s]
# epoch 103 || TRAIN_Loss:0.9079 ||VAL_Loss:0.8767
# Best epoch = 102
# 231it [00:08, 28.25it/s]
# 25it [00:00, 74.78it/s]
# epoch 104 || TRAIN_Loss:0.9093 ||VAL_Loss:0.8803
# Best epoch = 102
# 231it [00:08, 28.22it/s]
# 25it [00:00, 70.48it/s]
# epoch 105 || TRAIN_Loss:0.9079 ||VAL_Loss:0.8748
# Best epoch = 102
# 231it [00:08, 27.61it/s]
# 25it [00:00, 72.46it/s]
# epoch 106 || TRAIN_Loss:0.9092 ||VAL_Loss:0.8739
# Best epoch = 102
# 231it [00:08, 28.19it/s]
# 25it [00:00, 72.84it/s]
# epoch 107 || TRAIN_Loss:0.9077 ||VAL_Loss:0.8787
# Best epoch = 102
# 231it [00:08, 26.34it/s]
# 25it [00:00, 72.70it/s]
# epoch 108 || TRAIN_Loss:0.9073 ||VAL_Loss:0.8706
# Best epoch = 102
# 231it [00:08, 28.25it/s]
# 25it [00:00, 72.59it/s]
# epoch 109 || TRAIN_Loss:0.9037 ||VAL_Loss:0.8795
# Best epoch = 102
# 231it [00:08, 25.91it/s]
# 25it [00:00, 75.57it/s]
# epoch 110 || TRAIN_Loss:0.9068 ||VAL_Loss:0.8780
# Best epoch = 102
# 231it [00:08, 26.13it/s]
# 25it [00:00, 71.50it/s]
# epoch 111 || TRAIN_Loss:0.9061 ||VAL_Loss:0.8776
# Best epoch = 102
# 231it [00:08, 28.23it/s]
# 25it [00:00, 75.34it/s]
# epoch 112 || TRAIN_Loss:0.9042 ||VAL_Loss:0.8702
# Best epoch = 102
# 231it [00:08, 25.94it/s]
# 25it [00:00, 70.46it/s]
# epoch 113 || TRAIN_Loss:0.9049 ||VAL_Loss:0.8698
# Best epoch = 102
# 231it [00:08, 28.15it/s]
# 25it [00:00, 71.30it/s]
# epoch 114 || TRAIN_Loss:0.9014 ||VAL_Loss:0.8740
# Best epoch = 102
# 231it [00:08, 28.34it/s]
# 25it [00:00, 75.60it/s]
# epoch 115 || TRAIN_Loss:0.9043 ||VAL_Loss:0.8591
# Best epoch = 115
# 231it [00:08, 27.62it/s]
# 25it [00:00, 77.72it/s]
# epoch 116 || TRAIN_Loss:0.9026 ||VAL_Loss:0.8675
# Best epoch = 115
# 231it [00:08, 28.10it/s]
# 25it [00:00, 76.35it/s]
# epoch 117 || TRAIN_Loss:0.8996 ||VAL_Loss:0.8719
# Best epoch = 115
# 231it [00:08, 28.17it/s]
# 25it [00:00, 76.95it/s]
# epoch 118 || TRAIN_Loss:0.8997 ||VAL_Loss:0.8727
# Best epoch = 115
# 231it [00:08, 26.12it/s]
# 25it [00:00, 73.26it/s]
# epoch 119 || TRAIN_Loss:0.9020 ||VAL_Loss:0.8721
# Best epoch = 115
# 231it [00:08, 28.22it/s]
# 25it [00:00, 72.42it/s]
# epoch 120 || TRAIN_Loss:0.9007 ||VAL_Loss:0.8718
# Best epoch = 115
# 231it [00:08, 28.16it/s]
# 25it [00:00, 74.70it/s]
# epoch 121 || TRAIN_Loss:0.8995 ||VAL_Loss:0.8659
# Best epoch = 115
# 231it [00:08, 26.08it/s]
# 25it [00:00, 75.77it/s]
# epoch 122 || TRAIN_Loss:0.9006 ||VAL_Loss:0.8686
# Best epoch = 115
# 231it [00:08, 26.03it/s]
# 25it [00:00, 74.10it/s]
# epoch 123 || TRAIN_Loss:0.8996 ||VAL_Loss:0.8755
# Best epoch = 115
# 231it [00:08, 28.30it/s]
# 25it [00:00, 76.98it/s]
# epoch 124 || TRAIN_Loss:0.9006 ||VAL_Loss:0.8736
# Best epoch = 115
# 231it [00:08, 25.80it/s]
# 25it [00:00, 76.07it/s]
# epoch 125 || TRAIN_Loss:0.8985 ||VAL_Loss:0.8709
# Best epoch = 115
# 231it [00:08, 25.79it/s]
# 25it [00:00, 75.80it/s]
# epoch 126 || TRAIN_Loss:0.8995 ||VAL_Loss:0.8724
# Best epoch = 115
# 231it [00:08, 28.13it/s]
# 25it [00:00, 77.86it/s]
# epoch 127 || TRAIN_Loss:0.8990 ||VAL_Loss:0.8657
# Best epoch = 115
# 231it [00:08, 28.27it/s]
# 25it [00:00, 73.95it/s]
# epoch 128 || TRAIN_Loss:0.8990 ||VAL_Loss:0.8701
# Best epoch = 115
# 231it [00:08, 28.22it/s]
# 25it [00:00, 76.43it/s]
# epoch 129 || TRAIN_Loss:0.8973 ||VAL_Loss:0.8700
# Best epoch = 115
# 231it [00:08, 28.18it/s]
# 25it [00:00, 76.46it/s]
# epoch 130 || TRAIN_Loss:0.8991 ||VAL_Loss:0.8690
# Best epoch = 115
# 231it [00:08, 26.44it/s]
# 25it [00:00, 76.55it/s]
# epoch 131 || TRAIN_Loss:0.8951 ||VAL_Loss:0.8566
# Best epoch = 131
# 231it [00:08, 25.71it/s]
# 25it [00:00, 78.79it/s]
# epoch 132 || TRAIN_Loss:0.8990 ||VAL_Loss:0.8641
# Best epoch = 131
# 231it [00:08, 26.02it/s]
# 25it [00:00, 76.83it/s]
# epoch 133 || TRAIN_Loss:0.8971 ||VAL_Loss:0.8704
# Best epoch = 131
# 231it [00:08, 28.03it/s]
# 25it [00:00, 76.65it/s]
# epoch 134 || TRAIN_Loss:0.8962 ||VAL_Loss:0.8642
# Best epoch = 131
# 231it [00:09, 25.66it/s]
# 25it [00:00, 75.92it/s]
# epoch 135 || TRAIN_Loss:0.8959 ||VAL_Loss:0.8605
# Best epoch = 131
# 231it [00:08, 28.23it/s]
# 25it [00:00, 74.30it/s]
# epoch 136 || TRAIN_Loss:0.8927 ||VAL_Loss:0.8599
# Best epoch = 131
# 231it [00:08, 28.20it/s]
# 25it [00:00, 73.79it/s]
# epoch 137 || TRAIN_Loss:0.8968 ||VAL_Loss:0.8687
# Best epoch = 131
# 231it [00:08, 28.21it/s]
# 25it [00:00, 73.06it/s]
# epoch 138 || TRAIN_Loss:0.8933 ||VAL_Loss:0.8596
# Best epoch = 131
# 231it [00:08, 25.95it/s]
# 25it [00:00, 74.55it/s]
# epoch 139 || TRAIN_Loss:0.8957 ||VAL_Loss:0.8580
# Best epoch = 131
# 231it [00:08, 26.02it/s]
# 25it [00:00, 75.27it/s]
# epoch 140 || TRAIN_Loss:0.8943 ||VAL_Loss:0.8676
# Best epoch = 131
# 231it [00:08, 28.36it/s]
# 25it [00:00, 72.73it/s]
# epoch 141 || TRAIN_Loss:0.8928 ||VAL_Loss:0.8585
# Best epoch = 131
# 231it [00:08, 28.31it/s]
# 25it [00:00, 71.68it/s]
# epoch 142 || TRAIN_Loss:0.8954 ||VAL_Loss:0.8685
# Best epoch = 131
# 231it [00:08, 28.23it/s]
# 25it [00:00, 72.38it/s]
# epoch 143 || TRAIN_Loss:0.8940 ||VAL_Loss:0.8595
# Best epoch = 131
# 231it [00:08, 28.27it/s]
# 25it [00:00, 75.26it/s]
# epoch 144 || TRAIN_Loss:0.8919 ||VAL_Loss:0.8570
# Best epoch = 131
# 231it [00:08, 28.25it/s]
# 25it [00:00, 74.15it/s]
# epoch 145 || TRAIN_Loss:0.8936 ||VAL_Loss:0.8693
# Best epoch = 131
# 231it [00:08, 26.02it/s]
# 25it [00:00, 72.34it/s]
# epoch 146 || TRAIN_Loss:0.8923 ||VAL_Loss:0.8671
# Best epoch = 131
# 231it [00:08, 28.22it/s]
# 25it [00:00, 73.65it/s]
# epoch 147 || TRAIN_Loss:0.8928 ||VAL_Loss:0.8561
# Best epoch = 147
# 231it [00:08, 26.08it/s]
# 25it [00:00, 71.04it/s]
# epoch 148 || TRAIN_Loss:0.8923 ||VAL_Loss:0.8594
# Best epoch = 147
# 231it [00:08, 28.21it/s]
# 25it [00:00, 76.52it/s]
# epoch 149 || TRAIN_Loss:0.8921 ||VAL_Loss:0.8631
# Best epoch = 147
# 231it [00:08, 28.34it/s]
# 25it [00:00, 70.09it/s]
# epoch 150 || TRAIN_Loss:0.8927 ||VAL_Loss:0.8594
# Best epoch = 147
# 231it [00:08, 28.24it/s]
# 25it [00:00, 75.56it/s]
# epoch 151 || TRAIN_Loss:0.8923 ||VAL_Loss:0.8609
# Best epoch = 147
# 231it [00:08, 25.96it/s]
# 25it [00:00, 73.10it/s]
# epoch 152 || TRAIN_Loss:0.8930 ||VAL_Loss:0.8574
# Best epoch = 147
# 231it [00:08, 28.27it/s]
# 25it [00:00, 72.84it/s]
# epoch 153 || TRAIN_Loss:0.8900 ||VAL_Loss:0.8618
# Best epoch = 147
# 231it [00:08, 26.09it/s]
# 25it [00:00, 73.90it/s]
# epoch 154 || TRAIN_Loss:0.8901 ||VAL_Loss:0.8602
# Best epoch = 147
# 231it [00:08, 25.94it/s]
# 25it [00:00, 77.63it/s]
# epoch 155 || TRAIN_Loss:0.8913 ||VAL_Loss:0.8586
# Best epoch = 147
# 231it [00:08, 28.23it/s]
# 25it [00:00, 76.05it/s]
# epoch 156 || TRAIN_Loss:0.8916 ||VAL_Loss:0.8698
# Best epoch = 147
# 231it [00:08, 25.98it/s]
# 25it [00:00, 75.62it/s]
# epoch 157 || TRAIN_Loss:0.8905 ||VAL_Loss:0.8607
# Best epoch = 147
# 231it [00:08, 28.21it/s]
# 25it [00:00, 74.15it/s]
# epoch 158 || TRAIN_Loss:0.8907 ||VAL_Loss:0.8597
# Best epoch = 147
# 231it [00:08, 27.44it/s]
# 25it [00:00, 75.50it/s]
# epoch 159 || TRAIN_Loss:0.8910 ||VAL_Loss:0.8561
# Best epoch = 147
# 231it [00:08, 28.10it/s]
# 25it [00:00, 78.52it/s]
# epoch 160 || TRAIN_Loss:0.8910 ||VAL_Loss:0.8570
# Best epoch = 147
# 231it [00:08, 28.17it/s]
# 25it [00:00, 75.41it/s]
# epoch 161 || TRAIN_Loss:0.8906 ||VAL_Loss:0.8564
# Best epoch = 147
# 231it [00:08, 25.79it/s]
# 25it [00:00, 74.24it/s]
# epoch 162 || TRAIN_Loss:0.8885 ||VAL_Loss:0.8549
# Best epoch = 162
# 231it [00:09, 25.65it/s]
# 25it [00:00, 74.23it/s]
# epoch 163 || TRAIN_Loss:0.8898 ||VAL_Loss:0.8595
# Best epoch = 162
# 231it [00:08, 28.30it/s]
# 25it [00:00, 76.90it/s]
# epoch 164 || TRAIN_Loss:0.8885 ||VAL_Loss:0.8606
# Best epoch = 162
# 231it [00:08, 26.70it/s]
# 25it [00:00, 75.96it/s]
# epoch 165 || TRAIN_Loss:0.8892 ||VAL_Loss:0.8651
# Best epoch = 162
# 231it [00:08, 28.22it/s]
# 25it [00:00, 71.16it/s]
# epoch 166 || TRAIN_Loss:0.8889 ||VAL_Loss:0.8611
# Best epoch = 162
# 231it [00:08, 26.24it/s]
# 25it [00:00, 76.01it/s]
# epoch 167 || TRAIN_Loss:0.8880 ||VAL_Loss:0.8584
# Best epoch = 162
# 231it [00:08, 26.13it/s]
# 25it [00:00, 73.82it/s]
# epoch 168 || TRAIN_Loss:0.8907 ||VAL_Loss:0.8600
# Best epoch = 162
# 231it [00:08, 28.22it/s]
# 25it [00:00, 74.24it/s]
# epoch 169 || TRAIN_Loss:0.8865 ||VAL_Loss:0.8546
# Best epoch = 169
# 231it [00:08, 28.20it/s]
# 25it [00:00, 79.26it/s]
# epoch 170 || TRAIN_Loss:0.8916 ||VAL_Loss:0.8595
# Best epoch = 169
# 231it [00:08, 28.18it/s]
# 25it [00:00, 73.48it/s]
# epoch 171 || TRAIN_Loss:0.8914 ||VAL_Loss:0.8574
# Best epoch = 169
# 231it [00:08, 25.90it/s]
# 25it [00:00, 72.62it/s]
# epoch 172 || TRAIN_Loss:0.8885 ||VAL_Loss:0.8589
# Best epoch = 169
# 231it [00:08, 28.19it/s]
# 25it [00:00, 76.08it/s]
# epoch 173 || TRAIN_Loss:0.8909 ||VAL_Loss:0.8592
# Best epoch = 169
# 231it [00:08, 27.48it/s]
# 25it [00:00, 82.64it/s]
# epoch 174 || TRAIN_Loss:0.8912 ||VAL_Loss:0.8588
# Best epoch = 169
# 231it [00:08, 26.39it/s]
# 25it [00:00, 70.81it/s]
# epoch 175 || TRAIN_Loss:0.8879 ||VAL_Loss:0.8615
# Best epoch = 169
# 231it [00:08, 28.15it/s]
# 25it [00:00, 73.58it/s]
# epoch 176 || TRAIN_Loss:0.8900 ||VAL_Loss:0.8560
# Best epoch = 169
# 231it [00:08, 28.11it/s]
# 25it [00:00, 75.58it/s]
# epoch 177 || TRAIN_Loss:0.8901 ||VAL_Loss:0.8631
# Best epoch = 169
# 231it [00:08, 26.12it/s]
# 25it [00:00, 75.00it/s]
# epoch 178 || TRAIN_Loss:0.8906 ||VAL_Loss:0.8571
# Best epoch = 169
# 231it [00:08, 25.97it/s]
# 25it [00:00, 75.95it/s]
# epoch 179 || TRAIN_Loss:0.8913 ||VAL_Loss:0.8553
# Best epoch = 169
# 231it [00:08, 27.67it/s]
# 25it [00:00, 73.08it/s]
# epoch 180 || TRAIN_Loss:0.8906 ||VAL_Loss:0.8593
# Best epoch = 169
# 231it [00:08, 28.22it/s]
# 25it [00:00, 76.99it/s]
# epoch 181 || TRAIN_Loss:0.8884 ||VAL_Loss:0.8633
# Best epoch = 169
# 231it [00:08, 28.20it/s]
# 25it [00:00, 72.63it/s]
# epoch 182 || TRAIN_Loss:0.8906 ||VAL_Loss:0.8662
# Best epoch = 169
# 231it [00:08, 28.22it/s]
# 25it [00:00, 76.09it/s]
# epoch 183 || TRAIN_Loss:0.8890 ||VAL_Loss:0.8559
# Best epoch = 169
# 231it [00:08, 28.26it/s]
# 25it [00:00, 71.67it/s]
# epoch 184 || TRAIN_Loss:0.8890 ||VAL_Loss:0.8523
# Best epoch = 184
# 231it [00:08, 25.81it/s]
# 25it [00:00, 75.04it/s]
# epoch 185 || TRAIN_Loss:0.8882 ||VAL_Loss:0.8617
# Best epoch = 184
# 231it [00:08, 28.06it/s]
# 25it [00:00, 71.57it/s]
# epoch 186 || TRAIN_Loss:0.8854 ||VAL_Loss:0.8556
# Best epoch = 184
# 231it [00:08, 25.97it/s]
# 25it [00:00, 74.73it/s]
# epoch 187 || TRAIN_Loss:0.8915 ||VAL_Loss:0.8575
# Best epoch = 184
# 231it [00:08, 27.49it/s]
# 25it [00:00, 74.07it/s]
# epoch 188 || TRAIN_Loss:0.8880 ||VAL_Loss:0.8609
# Best epoch = 184
# 231it [00:08, 25.97it/s]
# 25it [00:00, 74.05it/s]
# epoch 189 || TRAIN_Loss:0.8884 ||VAL_Loss:0.8515
# Best epoch = 189
# 231it [00:08, 26.27it/s]
# 25it [00:00, 74.25it/s]
# epoch 190 || TRAIN_Loss:0.8893 ||VAL_Loss:0.8605
# Best epoch = 189
# 231it [00:08, 28.20it/s]
# 25it [00:00, 78.37it/s]
# epoch 191 || TRAIN_Loss:0.8894 ||VAL_Loss:0.8570
# Best epoch = 189
# 231it [00:08, 28.27it/s]
# 25it [00:00, 77.27it/s]
# epoch 192 || TRAIN_Loss:0.8889 ||VAL_Loss:0.8588
# Best epoch = 189
# 231it [00:08, 28.20it/s]
# 25it [00:00, 74.04it/s]
# epoch 193 || TRAIN_Loss:0.8888 ||VAL_Loss:0.8581
# Best epoch = 189
# 231it [00:08, 26.12it/s]
# 25it [00:00, 77.60it/s]
# epoch 194 || TRAIN_Loss:0.8864 ||VAL_Loss:0.8607
# Best epoch = 189
# 231it [00:08, 25.94it/s]
# 25it [00:00, 76.47it/s]
# epoch 195 || TRAIN_Loss:0.8883 ||VAL_Loss:0.8655
# Best epoch = 189
# 231it [00:08, 28.21it/s]
# 25it [00:00, 79.31it/s]
# epoch 196 || TRAIN_Loss:0.8898 ||VAL_Loss:0.8559
# Best epoch = 189
# 231it [00:08, 25.96it/s]
# 25it [00:00, 74.00it/s]
# epoch 197 || TRAIN_Loss:0.8898 ||VAL_Loss:0.8596
# Best epoch = 189
# 231it [00:08, 26.01it/s]
# 25it [00:00, 71.98it/s]
# epoch 198 || TRAIN_Loss:0.8892 ||VAL_Loss:0.8603
# Best epoch = 189
# 231it [00:08, 26.13it/s]
# 25it [00:00, 76.50it/s]
# epoch 199 || TRAIN_Loss:0.8882 ||VAL_Loss:0.8564
# Best epoch = 189
# 231it [00:08, 28.22it/s]
# 25it [00:00, 71.99it/s]
# epoch 200 || TRAIN_Loss:0.8893 ||VAL_Loss:0.8648
# Best epoch = 189

# %%
# テスト
main.main_cli([
    "test",  # run_mode
    "outputs/logbert/bert/T1105/ver_2/ratio_0.8/seq_len_128/r_seed_31/weights/ValTotalbest.pth", # 重みファイルまでの相対パス
    "64",   # eval_batchsize
    "cuda:0",     # gpu
])
# Out:
# ==================================================
# outputs/logbert/bert/T1105/ver_2/ratio_0.8/seq_len_128/r_seed_31
# ==================================================
# cuda:0 cuda:0
# Building Vocab
# 100%|██████████| 10343/10343 [00:00<00:00, 59275.94it/s]
# VOCAB SIZE: 55
# Processing normal test data: 100%|██████████| 2069/2069 [00:00<00:00, 3674.69it/s]
# Processing abnormal test data: 100%|██████████| 53/53 [00:00<00:00, 3420.76it/s]
# 100%|██████████| 32/32 [00:03<00:00,  9.30it/s]
# 100%|██████████| 53/53 [00:01<00:00, 38.65it/s]
# Saving test normal results
# Saving test abnormal results
# [seq_th, FP, TP, TN, FN, Precision, Recall, F1, TPR, FPR]
# threshold=0.000['15.0000', '9.0000', '2033.0000', '44.0000', '37.5000', '16.9811', '23.3766', '16.9811', '0.7324']
# threshold=0.001['15.0000', '9.0000', '2033.0000', '44.0000', '37.5000', '16.9811', '23.3766', '16.9811', '0.7324']
# threshold=0.002['15.0000', '9.0000', '2033.0000', '44.0000', '37.5000', '16.9811', '23.3766', '16.9811', '0.7324']
# threshold=0.003['15.0000', '9.0000', '2033.0000', '44.0000', '37.5000', '16.9811', '23.3766', '16.9811', '0.7324']
# threshold=0.004['15.0000', '9.0000', '2033.0000', '44.0000', '37.5000', '16.9811', '23.3766', '16.9811', '0.7324']
# threshold=0.005['15.0000', '9.0000', '2033.0000', '44.0000', '37.5000', '16.9811', '23.3766', '16.9811', '0.7324']
# threshold=0.006['15.0000', '9.0000', '2033.0000', '44.0000', '37.5000', '16.9811', '23.3766', '16.9811', '0.7324']
# threshold=0.007['15.0000', '9.0000', '2033.0000', '44.0000', '37.5000', '16.9811', '23.3766', '16.9811', '0.7324']
# threshold=0.008['15.0000', '9.0000', '2033.0000', '44.0000', '37.5000', '16.9811', '23.3766', '16.9811', '0.7324']
# threshold=0.009['15.0000', '9.0000', '2033.0000', '44.0000', '37.5000', '16.9811', '23.3766', '16.9811', '0.7324']
# threshold=0.010['15.0000', '9.0000', '2033.0000', '44.0000', '37.5000', '16.9811', '23.3766', '16.9811', '0.7324']
# threshold=0.011['15.0000', '9.0000', '2033.0000', '44.0000', '37.5000', '16.9811', '23.3766', '16.9811', '0.7324']
# threshold=0.012['15.0000', '8.0000', '2033.0000', '45.0000', '34.7826', '15.0943', '21.0526', '15.0943', '0.7324']
# threshold=0.013['12.0000', '8.0000', '2036.0000', '45.0000', '40.0000', '15.0943', '21.9178', '15.0943', '0.5859']
# threshold=0.014['12.0000', '8.0000', '2036.0000', '45.0000', '40.0000', '15.0943', '21.9178', '15.0943', '0.5859']
# threshold=0.015['12.0000', '7.0000', '2036.0000', '46.0000', '36.8421', '13.2075', '19.4444', '13.2075', '0.5859']
# threshold=0.016['12.0000', '6.0000', '2036.0000', '47.0000', '33.3333', '11.3208', '16.9014', '11.3208', '0.5859']
# threshold=0.017['12.0000', '6.0000', '2036.0000', '47.0000', '33.3333', '11.3208', '16.9014', '11.3208', '0.5859']
# threshold=0.018['12.0000', '6.0000', '2036.0000', '47.0000', '33.3333', '11.3208', '16.9014', '11.3208', '0.5859']
# threshold=0.019['12.0000', '6.0000', '2036.0000', '47.0000', '33.3333', '11.3208', '16.9014', '11.3208', '0.5859']
# threshold=0.020['12.0000', '6.0000', '2036.0000', '47.0000', '33.3333', '11.3208', '16.9014', '11.3208', '0.5859']

# %% [markdown]
# ## 1-2 VSCode1

# %% [markdown]
# ### 準備

# %%
parent_dir = "ScenarioData"
project_name = 'VSCode1'

# %% [markdown]
# ### evtx → csv

# %%
# test
input_dir = RAW_DIR/parent_dir/project_name
output_dir = INTERIM_DIR/project_name

preprocess.evtx_to_csv_without_eventdata_columns_samplingver(
    evtx_filepath = input_dir/"20240706063537_7EA74D56-6663-313B-2CC1-A7843FCD1AE6/Evtx/Security.evtx",
    output_dir = output_dir,
    output_filename = "security2_test",
)
# Out:
# Processing records:   5%|▌         | 4900/93912 [00:00<00:10, 8582.05it/s]
# Writing to CSV: 100%|██████████| 50/50 [00:00<00:00, 68556.78it/s]

# %%
# 実行
preprocess.evtx_to_csv_without_eventdata_columns(
    evtx_filepath = input_dir/"20240706063537_7EA74D56-6663-313B-2CC1-A7843FCD1AE6/Evtx/Security.evtx",
    output_dir = output_dir,
    output_filename = "security2",
)
# Out:
# Processing records: 100%|██████████| 93912/93912 [09:13<00:00, 169.80it/s]
# Writing to CSV: 100%|██████████| 93912/93912 [00:01<00:00, 67158.05it/s]

# %% [markdown]
# ### パース(Drain)

# %%
input_dir = INTERIM_DIR/project_name
output_dir = INTERIM_DIR/project_name

df = pd.read_csv(input_dir/"security.csv")
df = df.dropna(subset=["Content"]) # Contentカラムに欠損値をもつ行を削除
df.to_csv(input_dir / "security_clean.csv", index=False)

# %%
preprocess.parse_log(input_dir=input_dir, output_dir=output_dir, logfile_name='security_clean', parser_type="drain")

# %% [markdown]
# ## 1-3 WEB01

# %% [markdown]
# ### 準備

# %%
parent_dir = "ScenarioData"
project_name = 'WEB1'

# %% [markdown]
# ### evtx → csv

# %%
# test
input_dir = RAW_DIR/parent_dir/project_name
output_dir = INTERIM_DIR/project_name

preprocess.evtx_to_csv_without_eventdata_columns_samplingver(
    evtx_filepath = input_dir/"20240317044842_7EA74D56-6663-313B-2CC1-A7843FCD1AE6/Evtx/Security.evtx",
    output_dir = output_dir,
    output_filename = "security2_test",
)
# Out:
# Processing records:   2%|▏         | 4900/215806 [00:00<00:27, 7632.09it/s]
# Writing to CSV: 100%|██████████| 50/50 [00:00<00:00, 61230.72it/s]

# %%
# 実行
preprocess.evtx_to_csv_without_eventdata_columns(
    evtx_filepath = input_dir/"20240317044842_7EA74D56-6663-313B-2CC1-A7843FCD1AE6/Evtx/Security.evtx",
    output_dir = output_dir,
    output_filename = "security2",
)
# Out:
# Processing records: 100%|██████████| 215806/215806 [21:56<00:00, 163.89it/s]
# Writing to CSV: 100%|██████████| 215806/215806 [00:02<00:00, 72085.06it/s]

# %% [markdown]
# ### パース(Drain)

# %%
input_dir = INTERIM_DIR/project_name
output_dir = INTERIM_DIR/project_name

df = pd.read_csv(input_dir/"security.csv")
df = df.dropna(subset=["Content"]) # Contentカラムに欠損値をもつ行を削除
df.to_csv(input_dir / "security_clean.csv", index=False)

# %%
preprocess.parse_log(input_dir=input_dir, output_dir=output_dir, logfile_name='security_clean', parser_type="drain")
# Out:
# Parsing file: ../data/interim/WEB1/security_clean.csv
# Initial DataFrame:
#    Execution_ThreadID   Channel  Level  Opcode   Task  \
# 0                6000  Security      0       0  12804
# 1                6000  Security      0       0  12804
# 2                6000  Security      0       0  12804
# 3                6000  Security      0       0  12804
# 4                5136  Security      0       0  12810
#
#                    Correlation_ActivityID  \
# 0  {326660a5-67c0-0001-6861-6632c067da01}
# 1  {326660a5-67c0-0001-6861-6632c067da01}
# 2  {326660a5-67c0-0001-6861-6632c067da01}
# 3  {326660a5-67c0-0001-6861-6632c067da01}
# 4                                     NaN
#
#                                              Content  Security_UserID  \
# 0  SubjectUserSid=S-1-5-18;SubjectUserName=SWATTC...              NaN
# 1  SubjectUserSid=S-1-5-18;SubjectUserName=SWATTC...              NaN
# 2  SubjectUserSid=S-1-5-18;SubjectUserName=SWATTC...              NaN
# 3  SubjectUserSid=S-1-5-18;SubjectUserName=SWATTC...              NaN
# 4  ProcessId=8596;Application=\device\harddiskvol...              NaN
#
#              TimeCreated_SystemTime  EventID  Execution_ProcessID  \
# 0  2024-03-06 05:48:33.170567+00:00     4702                  692
# 1  2024-03-06 05:48:33.174620+00:00     4702                  692
# 2  2024-03-06 05:48:33.180763+00:00     4702                  692
# 3  2024-03-06 05:48:33.184887+00:00     4702                  692
# 4  2024-03-06 05:48:38.115097+00:00     5158                    4
#
#                             Provider_Guid  \
# 0  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 1  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 2  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 3  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 4  {54849625-5478-4994-a5ba-3e3b0328c30d}
#
#                          Provider_Name  Correlation_RelatedActivityID  \
# 0  Microsoft-Windows-Security-Auditing                            NaN
# 1  Microsoft-Windows-Security-Auditing                            NaN
# 2  Microsoft-Windows-Security-Auditing                            NaN
# 3  Microsoft-Windows-Security-Auditing                            NaN
# 4  Microsoft-Windows-Security-Auditing                            NaN
#
#    Version  EventRecordID            Keywords                Computer
# 0        1        1367106  0x8020000000000000  SWAttckd.swtestnet.com
# 1        1        1367107  0x8020000000000000  SWAttckd.swtestnet.com
# 2        1        1367108  0x8020000000000000  SWAttckd.swtestnet.com
# 3        1        1367109  0x8020000000000000  SWAttckd.swtestnet.com
# 4        0        1367110  0x8020000000000000  SWAttckd.swtestnet.com
# Total size after reading CSV: 215804
# Parsing done. [Time taken: 0:00:42.956216]

# %% [markdown]
# ## 1-4 WEB02

# %% [markdown]
# ### 準備

# %%
parent_dir = "ScenarioData"
project_name = 'WEB2'

# %% [markdown]
# ### evtx → csv

# %%
# test
input_dir = RAW_DIR/parent_dir/project_name
output_dir = INTERIM_DIR/project_name

preprocess.evtx_to_csv_without_eventdata_columns_samplingver(
    evtx_filepath = input_dir/"20240317051629_7EA74D56-6663-313B-2CC1-A7843FCD1AE6/Evtx/Security.evtx",
    output_dir = output_dir,
    output_filename = "security_test",
)
# Out:
# Processing records:   2%|▏         | 4900/215808 [00:00<00:27, 7709.37it/s]
# ../data/interim/WEB2/security_test.csv
# Writing to CSV: 100%|██████████| 50/50 [00:00<00:00, 61717.25it/s]

# %%
# 実行
preprocess.evtx_to_csv_without_eventdata_columns(
    evtx_filepath = input_dir/"20240317051629_7EA74D56-6663-313B-2CC1-A7843FCD1AE6/Evtx/Security.evtx",
    output_dir = output_dir,
    output_filename = "security",
)
# Out:
# Processing records: 100%|██████████| 215808/215808 [21:45<00:00, 165.31it/s]
# Writing to CSV: 100%|██████████| 215808/215808 [00:03<00:00, 68007.92it/s]

# %% [markdown]
# ### パース(Drain)

# %%
input_dir = INTERIM_DIR/project_name
output_dir = INTERIM_DIR/project_name

df = pd.read_csv(input_dir/"security.csv")
df = df.dropna(subset=["Content"]) # Contentカラムに欠損値をもつ行を削除
df.to_csv(input_dir / "security_clean.csv", index=False)

# %%
preprocess.parse_log(input_dir=input_dir, output_dir=output_dir, logfile_name='security_clean', parser_type="drain")
# Out:
# Parsing file: ../data/interim/WEB2/security_clean.csv
# Initial DataFrame:
#    Execution_ThreadID   Channel  Level  Opcode   Task  \
# 0                6000  Security      0       0  12804
# 1                6000  Security      0       0  12804
# 2                6000  Security      0       0  12804
# 3                6000  Security      0       0  12804
# 4                5136  Security      0       0  12810
#
#                    Correlation_ActivityID  \
# 0  {326660a5-67c0-0001-6861-6632c067da01}
# 1  {326660a5-67c0-0001-6861-6632c067da01}
# 2  {326660a5-67c0-0001-6861-6632c067da01}
# 3  {326660a5-67c0-0001-6861-6632c067da01}
# 4                                     NaN
#
#                                              Content  Security_UserID  \
# 0  SubjectUserSid=S-1-5-18;SubjectUserName=SWATTC...              NaN
# 1  SubjectUserSid=S-1-5-18;SubjectUserName=SWATTC...              NaN
# 2  SubjectUserSid=S-1-5-18;SubjectUserName=SWATTC...              NaN
# 3  SubjectUserSid=S-1-5-18;SubjectUserName=SWATTC...              NaN
# 4  ProcessId=8596;Application=\device\harddiskvol...              NaN
#
#              TimeCreated_SystemTime  EventID  Execution_ProcessID  \
# 0  2024-03-06 05:48:33.170567+00:00     4702                  692
# 1  2024-03-06 05:48:33.174620+00:00     4702                  692
# 2  2024-03-06 05:48:33.180763+00:00     4702                  692
# 3  2024-03-06 05:48:33.184887+00:00     4702                  692
# 4  2024-03-06 05:48:38.115097+00:00     5158                    4
#
#                             Provider_Guid  \
# 0  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 1  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 2  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 3  {54849625-5478-4994-a5ba-3e3b0328c30d}
# 4  {54849625-5478-4994-a5ba-3e3b0328c30d}
#
#                          Provider_Name  Correlation_RelatedActivityID  \
# 0  Microsoft-Windows-Security-Auditing                            NaN
# 1  Microsoft-Windows-Security-Auditing                            NaN
# 2  Microsoft-Windows-Security-Auditing                            NaN
# 3  Microsoft-Windows-Security-Auditing                            NaN
# 4  Microsoft-Windows-Security-Auditing                            NaN
#
#    Version  EventRecordID            Keywords                Computer
# 0        1        1367106  0x8020000000000000  SWAttckd.swtestnet.com
# 1        1        1367107  0x8020000000000000  SWAttckd.swtestnet.com
# 2        1        1367108  0x8020000000000000  SWAttckd.swtestnet.com
# 3        1        1367109  0x8020000000000000  SWAttckd.swtestnet.com
# 4        0        1367110  0x8020000000000000  SWAttckd.swtestnet.com
# Total size after reading CSV: 215806
# Parsing done. [Time taken: 0:00:42.786295]

# %% [markdown]
# ## 1-5 WEB03

# %% [markdown]
# ### 準備

# %%
parent_dir = "ScenarioData"
project_name = 'WEB3'

# %% [markdown]
# ### evtx → csv

# %%
# test
input_dir = RAW_DIR/parent_dir/project_name
output_dir = INTERIM_DIR/project_name

preprocess.evtx_to_csv_without_eventdata_columns_samplingver(
    evtx_filepath = input_dir/"20240317054607_7EA74D56-6663-313B-2CC1-A7843FCD1AE6/Evtx/Security.evtx",
    output_dir = output_dir,
    output_filename = "security_test",
)
# Out:
# Processing records:   2%|▏         | 4900/215773 [00:00<00:27, 7552.35it/s]
# Writing to CSV: 100%|██████████| 50/50 [00:00<00:00, 59629.00it/s]

# %%
# 実行
preprocess.evtx_to_csv_without_eventdata_columns(
    evtx_filepath = input_dir/"20240317054607_7EA74D56-6663-313B-2CC1-A7843FCD1AE6/Evtx/Security.evtx",
    output_dir = output_dir,
    output_filename = "security",
)
# Out:
# Processing records: 100%|██████████| 215773/215773 [22:06<00:00, 162.64it/s]
# Writing to CSV: 100%|██████████| 215773/215773 [00:02<00:00, 72782.44it/s]

# %% [markdown]
# ### パース(Drain)

# %%
input_dir = INTERIM_DIR/project_name
output_dir = INTERIM_DIR/project_name

df = pd.read_csv(input_dir/"security.csv")
df = df.dropna(subset=["Content"]) # Contentカラムに欠損値をもつ行を削除
df.to_csv(input_dir / "security_clean.csv", index=False)

# %%
preprocess.parse_log(input_dir=input_dir, output_dir=output_dir, logfile_name='security_clean', parser_type="drain")
# Out:
# Parsing file: ../data/interim/WEB3/security_clean.csv
# Initial DataFrame:
#     Task  Level                Computer  EventID  \
# 0  12804      0  SWAttckd.swtestnet.com     4702
# 1  12804      0  SWAttckd.swtestnet.com     4702
# 2  12804      0  SWAttckd.swtestnet.com     4702
# 3  12804      0  SWAttckd.swtestnet.com     4702
# 4  12810      0  SWAttckd.swtestnet.com     5158
#
#                    Correlation_ActivityID  \
# 0  {326660a5-67c0-0001-6861-6632c067da01}
# 1  {326660a5-67c0-0001-6861-6632c067da01}
# 2  {326660a5-67c0-0001-6861-6632c067da01}
# 3  {326660a5-67c0-0001-6861-6632c067da01}
# 4                                     NaN
#
#                                              Content  EventRecordID  \
# 0  SubjectUserSid=S-1-5-18;SubjectUserName=SWATTC...        1367106
# 1  SubjectUserSid=S-1-5-18;SubjectUserName=SWATTC...        1367107
# 2  SubjectUserSid=S-1-5-18;SubjectUserName=SWATTC...        1367108
# 3  SubjectUserSid=S-1-5-18;SubjectUserName=SWATTC...        1367109
# 4  ProcessId=8596;Application=\device\harddiskvol...        1367110
#
#                          Provider_Name  Security_UserID  Version  \
# 0  Microsoft-Windows-Security-Auditing              NaN        1
# 1  Microsoft-Windows-Security-Auditing              NaN        1
# 2  Microsoft-Windows-Security-Auditing              NaN        1
# 3  Microsoft-Windows-Security-Auditing              NaN        1
# 4  Microsoft-Windows-Security-Auditing              NaN        0
#
#              Keywords                           Provider_Guid   Channel  \
# 0  0x8020000000000000  {54849625-5478-4994-a5ba-3e3b0328c30d}  Security
# 1  0x8020000000000000  {54849625-5478-4994-a5ba-3e3b0328c30d}  Security
# 2  0x8020000000000000  {54849625-5478-4994-a5ba-3e3b0328c30d}  Security
# 3  0x8020000000000000  {54849625-5478-4994-a5ba-3e3b0328c30d}  Security
# 4  0x8020000000000000  {54849625-5478-4994-a5ba-3e3b0328c30d}  Security
#
#    Opcode  Correlation_RelatedActivityID            TimeCreated_SystemTime  \
# 0       0                            NaN  2024-03-06 05:48:33.170567+00:00
# 1       0                            NaN  2024-03-06 05:48:33.174620+00:00
# 2       0                            NaN  2024-03-06 05:48:33.180763+00:00
# 3       0                            NaN  2024-03-06 05:48:33.184887+00:00
# 4       0                            NaN  2024-03-06 05:48:38.115097+00:00
#
#    Execution_ProcessID  Execution_ThreadID
# 0                  692                6000
# 1                  692                6000
# 2                  692                6000
# 3                  692                6000
# 4                    4                5136
# Total size after reading CSV: 215771
# Parsing done. [Time taken: 0:00:42.736346]

# %% [markdown]
# ## 補足

# %% [markdown]
# ### "Channel="を削ぐ
# - 一応過程として残す

# %%
def remove_leading_channel_security(s):
    # NaN はそのまま返す
    if pd.isna(s):
        return s

    text = str(s)
    parts = text.split(";")

    # 先頭がちょうど "Channel=Security" なら、それを落とす
    if parts and parts[0] == "Channel=Security":
        parts = parts[1:]

    # 空文字を除いて再結合
    parts = [p for p in parts if p != ""]
    return ";".join(parts)

# %%
project_name = "WEB1"
input_dir = INTERIM_DIR/project_name

df = pd.read_csv(input_dir/"security.csv")
# Content カラムに適用
df["Content"] = df["Content"].apply(remove_leading_channel_security)
# ""をNaNに変換
df.loc[df["Content"] == "", "Content"] = np.nan

# %%
# 保存
df.to_csv(input_dir/"security_.csv", index=False)

# %% [markdown]
# ### HDFS
